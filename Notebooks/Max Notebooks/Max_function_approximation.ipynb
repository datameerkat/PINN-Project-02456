# %% [markdown]
# ## Neural networks for approximating functions
# This notebook is intended as a practice ground to learn how to use neural networks for approximating functions, are NNs are universal.

# %%
# import libraries
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from sklearn.metrics import r2_score

# %%
# define function(s)
f_poly = lambda x: 3*x**3*np.sin(x) + 2*x**2 + x
f_sin = lambda x: np.sin(x)
f_abs = lambda x: abs(x)

#define analytical derivatives
f_der_sin = lambda x: np.cos(x)

# %%
# create training and test set with the function
function = f_sin
derivative = f_der_sin
n_samples = 100
x_min = -10
x_max = 10
collocation_points = np.linspace(x_min, x_max, num=n_samples)

samples = np.empty([n_samples, 2])
for i, x in enumerate(collocation_points):
    samples[i, 0] = x
    samples[i, 1] = function(x)
np.random.shuffle(samples) # Shuffle the samples in-place
split_index = int(n_samples * 0.8) # define train/test split
train_x_np = samples[:split_index, 0]
train_y_np = samples[:split_index, 1]
test_x_np = samples[split_index:, 0]
test_y_np = samples[split_index:, 1]

# %%
# plot training and test set
plt.figure(figsize=(10, 5))
plt.plot(train_x_np, train_y_np, color = "blue", marker='o', linestyle='none', markersize=0.5)
plt.plot(test_x_np, test_y_np, color = "red", marker='o', linestyle='none', markersize=0.5)
plt.title("Collocation poinst of functions")
plt.legend(["Train", "Test"], loc="lower left")

# %%
#Change numpy array to tensor
train_x = torch.from_numpy(train_x_np).unsqueeze(1).float()
train_y = torch.from_numpy(train_y_np).unsqueeze(1).float()
test_x = torch.from_numpy(test_x_np).unsqueeze(1).float()
test_y = torch.from_numpy(test_y_np).unsqueeze(1).float()

#train_x.requires_grad = True
#train_y.requires_grad = True
#test_x.requires_grad = True
#test_y.requires_grad = True

# %%
# define network architecture
input_dim = 1
output_dim = 1
num_hidden = 300

class Net(nn.Module):
    def __init__(self, num_hidden):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(input_dim, num_hidden),
            nn.ReLU(),
            nn.Linear(num_hidden, num_hidden),
            nn.ReLU(),
            nn.Linear(num_hidden, output_dim),
        )

    def forward(self, x):
        y_out = self.linear_relu_stack(x)
        return y_out
    
net = Net(num_hidden)
    
# hyperparameters
learning_rate = 1e-5
batch_size = 20
num_epochs = 10000

#loss
loss_fn = nn.MSELoss()

#optimizer
optimizer = optim.Adam(net.parameters(), lr=learning_rate)

# %%
# train network

#getting epoch sizes
num_samples_train = train_x.shape[0]
num_batches_train = num_samples_train // batch_size
num_samples_test = test_x.shape[0]
num_batches_test = num_samples_test // batch_size

# setting up lists for handling loss/accuracy
train_acc, train_loss = [], []
test_acc, test_loss = [], []
cur_loss = 0
losses = []

get_slice = lambda i, size: range(i * size, (i + 1) * size) #get slices for each batch

for epoch in range(num_epochs):
    # Forward -> Backprob -> Update params
    ## Train
    cur_loss = 0
    net.train()
    for i in range(num_batches_train):
        optimizer.zero_grad()
        slce = get_slice(i, batch_size)
        output = net(train_x[slce])

        # compute gradients given loss
        y_batch = train_y[slce]
        batch_loss = loss_fn(output, y_batch)
        batch_loss.backward()
        optimizer.step()

        cur_loss += batch_loss
    losses.append(cur_loss / batch_size)

    net.eval()
    ### Evaluate training
    train_preds, train_targs = [], []
    for i in range(num_batches_train):
        slce = get_slice(i, batch_size)
        output = net(train_x[slce])

        preds = output.squeeze(1)

        train_targs += list(train_y[slce].numpy())
        train_preds += list(preds.data.numpy())

    ### Evaluate test
    test_preds, test_targs = [], []
    for i in range(num_batches_test):
        slce = get_slice(i, batch_size)

        output = net(test_x[slce])
        preds = output.squeeze(1)
        test_targs += list(test_y[slce].numpy())
        test_preds += list(preds.data.numpy())


    train_r2 = r2_score(train_targs, train_preds)
    test_r2 = r2_score(test_targs, test_preds)

    train_acc.append(train_r2)
    test_acc.append(test_r2)

    if epoch % 50 == 0:
        print("Epoch %2i : Train Loss %f , Train r2 %f, Test r2 %f" % (
                epoch+1, losses[-1], train_r2, test_r2))

epoch = np.arange(len(train_acc))
plt.figure()
plt.plot(epoch, train_acc, 'r', epoch, test_acc, 'b')
plt.legend(['Train acc','Test acc'])
plt.xlabel('Updates'), plt.ylabel('R2')
# Out:
# Epoch  1 : Train Loss 0.161019 , Train r2 -0.549476, Test r2 -0.377859
# Epoch 51 : Train Loss 0.085919 , Train r2 0.118415, Test r2 0.073753
# Epoch 101 : Train Loss 0.081115 , Train r2 0.167467, Test r2 0.115784
# Epoch 151 : Train Loss 0.077658 , Train r2 0.202956, Test r2 0.143344
# Epoch 201 : Train Loss 0.074673 , Train r2 0.233612, Test r2 0.166074
# Epoch 251 : Train Loss 0.071846 , Train r2 0.262643, Test r2 0.186961
# Epoch 301 : Train Loss 0.069131 , Train r2 0.290561, Test r2 0.206982
# Epoch 351 : Train Loss 0.066543 , Train r2 0.317143, Test r2 0.226018
# Epoch 401 : Train Loss 0.064061 , Train r2 0.342646, Test r2 0.243923
# Epoch 451 : Train Loss 0.061694 , Train r2 0.366966, Test r2 0.261169
# Epoch 501 : Train Loss 0.059430 , Train r2 0.390239, Test r2 0.277825
# Epoch 551 : Train Loss 0.057301 , Train r2 0.412087, Test r2 0.293193
# Epoch 601 : Train Loss 0.055301 , Train r2 0.432636, Test r2 0.307447
# Epoch 651 : Train Loss 0.053420 , Train r2 0.451951, Test r2 0.320605
# Epoch 701 : Train Loss 0.051659 , Train r2 0.470037, Test r2 0.332919
# Epoch 751 : Train Loss 0.050004 , Train r2 0.487034, Test r2 0.344407
# Epoch 801 : Train Loss 0.048451 , Train r2 0.502969, Test r2 0.355274
# Epoch 851 : Train Loss 0.046995 , Train r2 0.517940, Test r2 0.365291
# Epoch 901 : Train Loss 0.045661 , Train r2 0.531625, Test r2 0.373821
# Epoch 951 : Train Loss 0.044426 , Train r2 0.544313, Test r2 0.381899
# Epoch 1001 : Train Loss 0.043282 , Train r2 0.556065, Test r2 0.389440
# Epoch 1051 : Train Loss 0.042229 , Train r2 0.566868, Test r2 0.396395
# Epoch 1101 : Train Loss 0.041261 , Train r2 0.576804, Test r2 0.403066
# Epoch 1151 : Train Loss 0.040367 , Train r2 0.585993, Test r2 0.409535
# Epoch 1201 : Train Loss 0.039547 , Train r2 0.594407, Test r2 0.415378
# Epoch 1251 : Train Loss 0.038778 , Train r2 0.602304, Test r2 0.420188
# Epoch 1301 : Train Loss 0.038077 , Train r2 0.609503, Test r2 0.424381
# Epoch 1351 : Train Loss 0.037433 , Train r2 0.616105, Test r2 0.428800
# Epoch 1401 : Train Loss 0.036843 , Train r2 0.622166, Test r2 0.433156
# Epoch 1451 : Train Loss 0.036295 , Train r2 0.627800, Test r2 0.437697
# Epoch 1501 : Train Loss 0.035783 , Train r2 0.633056, Test r2 0.441841
# Epoch 1551 : Train Loss 0.035308 , Train r2 0.637941, Test r2 0.445887
# Epoch 1601 : Train Loss 0.034843 , Train r2 0.642707, Test r2 0.449484
# Epoch 1651 : Train Loss 0.034437 , Train r2 0.646865, Test r2 0.452720
# Epoch 1701 : Train Loss 0.034063 , Train r2 0.650721, Test r2 0.456366
# Epoch 1751 : Train Loss 0.033712 , Train r2 0.654328, Test r2 0.460357
# Epoch 1801 : Train Loss 0.033385 , Train r2 0.657684, Test r2 0.463631
# Epoch 1851 : Train Loss 0.033079 , Train r2 0.660829, Test r2 0.466724
# Epoch 1901 : Train Loss 0.032791 , Train r2 0.663786, Test r2 0.469770
# Epoch 1951 : Train Loss 0.032516 , Train r2 0.666607, Test r2 0.472482
# Epoch 2001 : Train Loss 0.032250 , Train r2 0.669333, Test r2 0.475345
# Epoch 2051 : Train Loss 0.031993 , Train r2 0.671976, Test r2 0.478989
# Epoch 2101 : Train Loss 0.031747 , Train r2 0.674519, Test r2 0.482732
# Epoch 2151 : Train Loss 0.031507 , Train r2 0.676980, Test r2 0.486397
# Epoch 2201 : Train Loss 0.031275 , Train r2 0.679363, Test r2 0.489846
# Epoch 2251 : Train Loss 0.031048 , Train r2 0.681696, Test r2 0.493672
# Epoch 2301 : Train Loss 0.030827 , Train r2 0.683973, Test r2 0.497194
# Epoch 2351 : Train Loss 0.030608 , Train r2 0.686214, Test r2 0.500951
# Epoch 2401 : Train Loss 0.030390 , Train r2 0.688444, Test r2 0.504380
# Epoch 2451 : Train Loss 0.030177 , Train r2 0.690639, Test r2 0.508210
# Epoch 2501 : Train Loss 0.029948 , Train r2 0.692999, Test r2 0.511766
# Epoch 2551 : Train Loss 0.029735 , Train r2 0.695181, Test r2 0.514967
# Epoch 2601 : Train Loss 0.029523 , Train r2 0.697355, Test r2 0.518591
# Epoch 2651 : Train Loss 0.029311 , Train r2 0.699532, Test r2 0.522302
# Epoch 2701 : Train Loss 0.029100 , Train r2 0.701708, Test r2 0.525841
# Epoch 2751 : Train Loss 0.028887 , Train r2 0.703899, Test r2 0.529240
# Epoch 2801 : Train Loss 0.028673 , Train r2 0.706095, Test r2 0.532760
# Epoch 2851 : Train Loss 0.028457 , Train r2 0.708299, Test r2 0.536436
# Epoch 2901 : Train Loss 0.028240 , Train r2 0.710531, Test r2 0.539952
# Epoch 2951 : Train Loss 0.028023 , Train r2 0.712764, Test r2 0.543704
# Epoch 3001 : Train Loss 0.027806 , Train r2 0.715004, Test r2 0.547392
# Epoch 3051 : Train Loss 0.027586 , Train r2 0.717266, Test r2 0.551220
# Epoch 3101 : Train Loss 0.027364 , Train r2 0.719543, Test r2 0.555146
# Epoch 3151 : Train Loss 0.027142 , Train r2 0.721824, Test r2 0.558922
# Epoch 3201 : Train Loss 0.026918 , Train r2 0.724124, Test r2 0.562527
# Epoch 3251 : Train Loss 0.026692 , Train r2 0.726450, Test r2 0.566169
# Epoch 3301 : Train Loss 0.026461 , Train r2 0.728810, Test r2 0.569874
# Epoch 3351 : Train Loss 0.026229 , Train r2 0.731198, Test r2 0.573917
# Epoch 3401 : Train Loss 0.025995 , Train r2 0.733611, Test r2 0.577415
# Epoch 3451 : Train Loss 0.025756 , Train r2 0.736049, Test r2 0.581413
# Epoch 3501 : Train Loss 0.025518 , Train r2 0.738493, Test r2 0.585338
# Epoch 3551 : Train Loss 0.025280 , Train r2 0.740943, Test r2 0.589640
# Epoch 3601 : Train Loss 0.025042 , Train r2 0.743380, Test r2 0.593280
# Epoch 3651 : Train Loss 0.024806 , Train r2 0.745810, Test r2 0.597121
# Epoch 3701 : Train Loss 0.024568 , Train r2 0.748254, Test r2 0.601095
# Epoch 3751 : Train Loss 0.024333 , Train r2 0.750674, Test r2 0.605113
# Epoch 3801 : Train Loss 0.024096 , Train r2 0.753098, Test r2 0.609275
# Epoch 3851 : Train Loss 0.023859 , Train r2 0.755529, Test r2 0.613359
# Epoch 3901 : Train Loss 0.023622 , Train r2 0.757956, Test r2 0.617526
# Epoch 3951 : Train Loss 0.023388 , Train r2 0.760366, Test r2 0.622062
# Epoch 4001 : Train Loss 0.023154 , Train r2 0.762780, Test r2 0.626214
# Epoch 4051 : Train Loss 0.022918 , Train r2 0.765192, Test r2 0.630324
# Epoch 4101 : Train Loss 0.022683 , Train r2 0.767612, Test r2 0.634400
# Epoch 4151 : Train Loss 0.022446 , Train r2 0.770038, Test r2 0.638804
# Epoch 4201 : Train Loss 0.022209 , Train r2 0.772477, Test r2 0.642823
# Epoch 4251 : Train Loss 0.021971 , Train r2 0.774922, Test r2 0.646857
# Epoch 4301 : Train Loss 0.021732 , Train r2 0.777371, Test r2 0.651083
# Epoch 4351 : Train Loss 0.021493 , Train r2 0.779827, Test r2 0.655085
# Epoch 4401 : Train Loss 0.021254 , Train r2 0.782287, Test r2 0.659065
# Epoch 4451 : Train Loss 0.021013 , Train r2 0.784750, Test r2 0.663064
# Epoch 4501 : Train Loss 0.020771 , Train r2 0.787232, Test r2 0.667014
# Epoch 4551 : Train Loss 0.020529 , Train r2 0.789717, Test r2 0.671286
# Epoch 4601 : Train Loss 0.020287 , Train r2 0.792206, Test r2 0.675489
# Epoch 4651 : Train Loss 0.020045 , Train r2 0.794694, Test r2 0.679459
# Epoch 4701 : Train Loss 0.019802 , Train r2 0.797185, Test r2 0.683682
# Epoch 4751 : Train Loss 0.019560 , Train r2 0.799673, Test r2 0.687698
# Epoch 4801 : Train Loss 0.019317 , Train r2 0.802175, Test r2 0.692122
# Epoch 4851 : Train Loss 0.019073 , Train r2 0.804675, Test r2 0.696281
# Epoch 4901 : Train Loss 0.018828 , Train r2 0.807186, Test r2 0.700359
# Epoch 4951 : Train Loss 0.018580 , Train r2 0.809736, Test r2 0.704903
# Epoch 5001 : Train Loss 0.018331 , Train r2 0.812285, Test r2 0.709190
# Epoch 5051 : Train Loss 0.018082 , Train r2 0.814852, Test r2 0.713592
# Epoch 5101 : Train Loss 0.017828 , Train r2 0.817449, Test r2 0.717955
# Epoch 5151 : Train Loss 0.017574 , Train r2 0.820061, Test r2 0.722187
# Epoch 5201 : Train Loss 0.017320 , Train r2 0.822672, Test r2 0.726703
# Epoch 5251 : Train Loss 0.017063 , Train r2 0.825296, Test r2 0.730784
# Epoch 5301 : Train Loss 0.016807 , Train r2 0.827931, Test r2 0.735232
# Epoch 5351 : Train Loss 0.016552 , Train r2 0.830550, Test r2 0.739592
# Epoch 5401 : Train Loss 0.016297 , Train r2 0.833171, Test r2 0.743919
# Epoch 5451 : Train Loss 0.016041 , Train r2 0.835792, Test r2 0.748041
# Epoch 5501 : Train Loss 0.015789 , Train r2 0.838384, Test r2 0.752119
# Epoch 5551 : Train Loss 0.015536 , Train r2 0.840981, Test r2 0.756340
# Epoch 5601 : Train Loss 0.015290 , Train r2 0.843506, Test r2 0.760647
# Epoch 5651 : Train Loss 0.015041 , Train r2 0.846065, Test r2 0.765005
# Epoch 5701 : Train Loss 0.014792 , Train r2 0.848624, Test r2 0.768899
# Epoch 5751 : Train Loss 0.014548 , Train r2 0.851117, Test r2 0.773363
# Epoch 5801 : Train Loss 0.014307 , Train r2 0.853594, Test r2 0.777499
# Epoch 5851 : Train Loss 0.014066 , Train r2 0.856072, Test r2 0.781722
# Epoch 5901 : Train Loss 0.013822 , Train r2 0.858582, Test r2 0.785807
# Epoch 5951 : Train Loss 0.013576 , Train r2 0.861099, Test r2 0.790056
# Epoch 6001 : Train Loss 0.013330 , Train r2 0.863629, Test r2 0.794110
# Epoch 6051 : Train Loss 0.013080 , Train r2 0.866190, Test r2 0.798408
# Epoch 6101 : Train Loss 0.012833 , Train r2 0.868726, Test r2 0.802430
# Epoch 6151 : Train Loss 0.012588 , Train r2 0.871243, Test r2 0.806354
# Epoch 6201 : Train Loss 0.012348 , Train r2 0.873699, Test r2 0.811006
# Epoch 6251 : Train Loss 0.012112 , Train r2 0.876120, Test r2 0.815261
# Epoch 6301 : Train Loss 0.011882 , Train r2 0.878482, Test r2 0.819376
# Epoch 6351 : Train Loss 0.011654 , Train r2 0.880823, Test r2 0.823562
# Epoch 6401 : Train Loss 0.011431 , Train r2 0.883115, Test r2 0.827358
# Epoch 6451 : Train Loss 0.011211 , Train r2 0.885373, Test r2 0.831211
# Epoch 6501 : Train Loss 0.010993 , Train r2 0.887612, Test r2 0.834965
# Epoch 6551 : Train Loss 0.010776 , Train r2 0.889834, Test r2 0.838731
# Epoch 6601 : Train Loss 0.010562 , Train r2 0.892037, Test r2 0.842202
# Epoch 6651 : Train Loss 0.010349 , Train r2 0.894221, Test r2 0.845809
# Epoch 6701 : Train Loss 0.010139 , Train r2 0.896374, Test r2 0.849412
# Epoch 6751 : Train Loss 0.009933 , Train r2 0.898489, Test r2 0.852969
# Epoch 6801 : Train Loss 0.009729 , Train r2 0.900580, Test r2 0.856498
# Epoch 6851 : Train Loss 0.009528 , Train r2 0.902649, Test r2 0.859858
# Epoch 6901 : Train Loss 0.009328 , Train r2 0.904694, Test r2 0.863194
# Epoch 6951 : Train Loss 0.009131 , Train r2 0.906715, Test r2 0.866544
# Epoch 7001 : Train Loss 0.008937 , Train r2 0.908711, Test r2 0.869856
# Epoch 7051 : Train Loss 0.008744 , Train r2 0.910685, Test r2 0.873173
# Epoch 7101 : Train Loss 0.008555 , Train r2 0.912630, Test r2 0.876277
# Epoch 7151 : Train Loss 0.008367 , Train r2 0.914553, Test r2 0.879493
# Epoch 7201 : Train Loss 0.008182 , Train r2 0.916447, Test r2 0.882491
# Epoch 7251 : Train Loss 0.008001 , Train r2 0.918313, Test r2 0.885530
# Epoch 7301 : Train Loss 0.007821 , Train r2 0.920154, Test r2 0.888526
# Epoch 7351 : Train Loss 0.007645 , Train r2 0.921964, Test r2 0.891505
# Epoch 7401 : Train Loss 0.007470 , Train r2 0.923749, Test r2 0.894541
# Epoch 7451 : Train Loss 0.007300 , Train r2 0.925504, Test r2 0.897319
# Epoch 7501 : Train Loss 0.007131 , Train r2 0.927231, Test r2 0.900102
# Epoch 7551 : Train Loss 0.006965 , Train r2 0.928928, Test r2 0.902929
# Epoch 7601 : Train Loss 0.006803 , Train r2 0.930595, Test r2 0.905682
# Epoch 7651 : Train Loss 0.006643 , Train r2 0.932234, Test r2 0.908354
# Epoch 7701 : Train Loss 0.006486 , Train r2 0.933844, Test r2 0.911003
# Epoch 7751 : Train Loss 0.006332 , Train r2 0.935425, Test r2 0.913631
# Epoch 7801 : Train Loss 0.006180 , Train r2 0.936979, Test r2 0.916183
# Epoch 7851 : Train Loss 0.006032 , Train r2 0.938503, Test r2 0.918747
# Epoch 7901 : Train Loss 0.005886 , Train r2 0.939998, Test r2 0.921193
# Epoch 7951 : Train Loss 0.005744 , Train r2 0.941461, Test r2 0.923596
# Epoch 8001 : Train Loss 0.005603 , Train r2 0.942901, Test r2 0.925985
# Epoch 8051 : Train Loss 0.005466 , Train r2 0.944308, Test r2 0.928306
# Epoch 8101 : Train Loss 0.005331 , Train r2 0.945685, Test r2 0.930599
# Epoch 8151 : Train Loss 0.005200 , Train r2 0.947031, Test r2 0.932826
# Epoch 8201 : Train Loss 0.005072 , Train r2 0.948347, Test r2 0.934985
# Epoch 8251 : Train Loss 0.004946 , Train r2 0.949632, Test r2 0.937101
# Epoch 8301 : Train Loss 0.004824 , Train r2 0.950887, Test r2 0.939154
# Epoch 8351 : Train Loss 0.004705 , Train r2 0.952110, Test r2 0.941137
# Epoch 8401 : Train Loss 0.004588 , Train r2 0.953303, Test r2 0.942965
# Epoch 8451 : Train Loss 0.004475 , Train r2 0.954469, Test r2 0.944774
# Epoch 8501 : Train Loss 0.004364 , Train r2 0.955606, Test r2 0.946565
# Epoch 8551 : Train Loss 0.004255 , Train r2 0.956718, Test r2 0.948274
# Epoch 8601 : Train Loss 0.004149 , Train r2 0.957803, Test r2 0.949965
# Epoch 8651 : Train Loss 0.004045 , Train r2 0.958864, Test r2 0.951598
# Epoch 8701 : Train Loss 0.003945 , Train r2 0.959896, Test r2 0.953189
# Epoch 8751 : Train Loss 0.003846 , Train r2 0.960902, Test r2 0.954762
# Epoch 8801 : Train Loss 0.003750 , Train r2 0.961883, Test r2 0.956288
# Epoch 8851 : Train Loss 0.003657 , Train r2 0.962838, Test r2 0.957769
# Epoch 8901 : Train Loss 0.003566 , Train r2 0.963769, Test r2 0.959236
# Epoch 8951 : Train Loss 0.003477 , Train r2 0.964678, Test r2 0.960700
# Epoch 9001 : Train Loss 0.003390 , Train r2 0.965567, Test r2 0.962101
# Epoch 9051 : Train Loss 0.003306 , Train r2 0.966438, Test r2 0.963515
# Epoch 9101 : Train Loss 0.003223 , Train r2 0.967286, Test r2 0.964921
# Epoch 9151 : Train Loss 0.003143 , Train r2 0.968109, Test r2 0.966260
# Epoch 9201 : Train Loss 0.003064 , Train r2 0.968911, Test r2 0.967432
# Epoch 9251 : Train Loss 0.002987 , Train r2 0.969697, Test r2 0.968545
# Epoch 9301 : Train Loss 0.002912 , Train r2 0.970468, Test r2 0.969638
# Epoch 9351 : Train Loss 0.002838 , Train r2 0.971225, Test r2 0.970710
# Epoch 9401 : Train Loss 0.002765 , Train r2 0.971969, Test r2 0.971766
# Epoch 9451 : Train Loss 0.002694 , Train r2 0.972697, Test r2 0.972790
# Epoch 9501 : Train Loss 0.002624 , Train r2 0.973411, Test r2 0.973787
# Epoch 9551 : Train Loss 0.002555 , Train r2 0.974109, Test r2 0.974735
# Epoch 9601 : Train Loss 0.002488 , Train r2 0.974795, Test r2 0.975692
# Epoch 9651 : Train Loss 0.002423 , Train r2 0.975464, Test r2 0.976639
# Epoch 9701 : Train Loss 0.002358 , Train r2 0.976119, Test r2 0.977508
# Epoch 9751 : Train Loss 0.002296 , Train r2 0.976758, Test r2 0.978442
# Epoch 9801 : Train Loss 0.002235 , Train r2 0.977380, Test r2 0.979319
# Epoch 9851 : Train Loss 0.002176 , Train r2 0.977987, Test r2 0.980136
# Epoch 9901 : Train Loss 0.002118 , Train r2 0.978579, Test r2 0.980944
# Epoch 9951 : Train Loss 0.002062 , Train r2 0.979153, Test r2 0.981800
# (Text(0.5, 0, 'Updates'), Text(0, 0.5, 'R2'))

# %%
 # evaluate network at different points, show results
test_x.requires_grad = True
test_y_eval = net(test_x) #predictes y values of test set of the trained model
test_y_eval_np = test_y_eval.detach().numpy() #converts it to numpy array

# plot analytical solution vs predicted values of test set
plt.figure(figsize=(10, 5))
plt.plot(test_x_np, test_y_np, color = "blue", marker='o', linestyle='none', markersize=0.5)
plt.plot(test_x_np, test_y_eval_np, color = "red", marker='o', linestyle='none', markersize=0.5)
plt.title("Predicted values of NN")
plt.legend(["Analytical", "Neural net"], loc="lower left")

# %%
# compute derivatives
computed_der = torch.autograd.grad(test_y_eval, test_x, grad_outputs=torch.ones_like(test_y_eval))[0]

# %%
analytical_der = np.empty([len(test_x)])
for i, x in enumerate(test_x_np):
    analytical_der[i] = derivative(x)

# %%
# plot analytical solution vs predicted values of derivatives
plt.figure(figsize=(10, 5))
plt.plot(test_x_np, analytical_der, color = "blue", marker='o', linestyle='none', markersize=0.5)
plt.plot(test_x_np, computed_der.detach().numpy(), color = "red", marker='o', linestyle='none', markersize=0.5)
plt.title("Predicted values of NN")
plt.legend(["Analytical", "Neural net"], loc="lower left")
