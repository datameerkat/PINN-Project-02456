# %% [markdown]
# # SIR modelling as in: Data-driven approaches for predicting spread of infectious diseases through DINNs: Disease Informed Neural Networks
#
# Notes for self:
# SIR stands for
# - Susceptible
# - Infective
# - Removed (recovered)
#
# S -> I -> R
# The transfer rate from S->I is beta. Called transmission rate.
# The transfer rate from I->R is alpha. Called recovery rate.
#
# The system of ODE with the 3 variables is as follows. All variables are functions of time t:
# dS/dt = -beta * S * I
# dI/dt = beta * S * I - alpha * I
# dR/dt = alpha I
#
# Assumed that no one has recovered at the onset:
# R(0) = 0
# Initial number of Infected is I(0) = I_0
#
# ## How DINN's are trained
# 1. The ODE's are solved with known initial conditions and true parameters (I think they mean alpha, beta etc.).
#     This step results in a data series of S, I, R for each t. They use 50-100 points.
#     They restrict the parameters around the true values. Not stated by how much.
# 2. For this set of data points we train using loss from
#     - Data point loss
#     - ODE loss
#
# Note: I am a unsure how they obtain the parameters alpha beta from the network. They train the network to take in a time t and
# output a S, I, R. How does this result in an alpha/beta etc.

# %%
from scipy.integrate import solve_ivp
import torch
from torch import nn
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

from torch.nn.parameter import Parameter
#from torchvision.datasets import MNIST
from timeit import default_timer as tdt

import wandb

#from softadapt import SoftAdapt, NormalizedSoftAdapt, LossWeightedSoftAdapt

if torch.cuda.is_available():
    my_device = 'cuda'
else:
    my_device = 'cpu'
    
has_been_run = True

wandb_on = True

# %%
# login in Weights&Biases
if wandb_on:
    wandb.login()
# Out:
# wandb: Currently logged in as: datameerkat (dl_pinn). Use `wandb login --relogin` to force relogin

# %%
# Time setup
n_days = 1000
t = np.arange(0, n_days+1, 1)

## Disease setup
alpha = 0.01
beta = 0.025

# Initial conditions
N = 1000.0   # Population size
I0 = 100.0/N      # Initial number of infected
R0 = 0.0/N      # Initial number of recovered
S0 = 1 - I0 - R0    # Initial number of susceptible

# %% [markdown]
# # Solving the system numerically

# %%
# Solve numerically
def SIR_model_num(t, y, N, beta, alpha):
    S, I, R = y
    dSdt = -beta * S * I
    dIdt = beta * S * I - alpha * I
    dRdt = alpha * I
    return [dSdt, dIdt, dRdt]

# Setup initial conditions 
y0 = [S0, I0, R0]

# Solve using LSODA method from scipy
sol = solve_ivp(SIR_model_num, [t[0], t[-1]], y0, args=(N/N, beta, alpha), t_eval=t, method='LSODA')

S_data = sol.y[0]
I_data = sol.y[1]
R_data = sol.y[2]
print(sol.message)
# Out:
# The solver successfully reached the end of the integration interval.

# %%
# Plot numerical solution
fig, ax = plt.subplots(1, 1, figsize=(8,2))
ax.plot(t, S_data, linestyle='--', label='S')
ax.plot(t, I_data, linestyle='--', label='I')
ax.plot(t, R_data, linestyle='--', label='R')

ax.set_xlabel('Time [days]')
ax.set_ylabel('S(t), I(t), R(t) [Count]')
ax.legend()
ax.set_title('Numerical Solution to SIR model')
# Out:
# Text(0.5, 1.0, 'Numerical Solution to SIR model')

# %% [markdown]
# # Training a neural network to solve the ODE system
# In the following I will setup a network for solving the system of ODE's (SIR model).
# I will assume we know beta and alpha here which is of course cheating. The idea is to figure out what
# network size we need in order to capture the dynamics.
# ## Description
# ### Loss functions
# Two loss functions will be implemented at first
# 1. The ODE loss
# 2. The initial condition loss
# Later loss based on data points will be implemented
# ### Network structure
# The input for the network will be time t.
# The output of the network will be U.
# where
# S = U[0]
# I = U[1]
# R = U[2]

# %%
# ================== Loss functions ==================
# Defining loss function for reasons unknown
torch_MSE_loss = torch.nn.MSELoss()

# Loss for the ODE
def get_loss_ODE(net, t, alpha, beta):
    # Find network solution
    U = net(t)
    S = U[:,0]
    I = U[:,1]
    R = U[:,2]
    
    # Calculate derivatives
    dSdt = torch.autograd.grad(S, t, grad_outputs=torch.ones_like(S), create_graph=True)[0].squeeze()
    dIdt = torch.autograd.grad(I, t, grad_outputs=torch.ones_like(I), create_graph=True)[0].squeeze()
    dRdt = torch.autograd.grad(R, t, grad_outputs=torch.ones_like(R), create_graph=True)[0].squeeze()
    
    # Calculate loss
    # Error1:
    rhs_S = -beta * S * I
    loss1 = torch_MSE_loss(dSdt, rhs_S)
    # Error2:
    rhs_I = beta * S * I - alpha * I
    loss2 = torch_MSE_loss(dIdt, rhs_I)
    # Error3:
    rhs_R = alpha * I
    loss3 = torch_MSE_loss(dRdt, rhs_R)
    
    # Summing the loss. Consider returning all 3 and doing the adaptiveWeight loss on them.
    loss_total = loss1 + loss2 + loss3
    
    return loss_total

# Loss for the initial condition
def get_loss_IC(net, t0, S0, I0, R0):
    # Find network solution
    U = net(t0).view(1,-1)   # reshape as there is only 1 time "t".
    S0_net = U[:,0]
    I0_net = U[:,1]
    R0_net = U[:,2]
    
    # Calculate loss
    loss1 = torch_MSE_loss(S0, S0_net)
    loss2 = torch_MSE_loss(I0, I0_net)
    loss3 = torch_MSE_loss(R0, R0_net)
    
    # Summing the loss. Consider retutning all 3 and doing the adaptiveWeight loss on them.
    loss_total = loss1 + loss2 + loss3 
    
    return loss_total

def get_data_point_loss(net, t_data, S_data, I_data, R_data):
    # Find network solution
    U = net(t_data.view(-1,1))   # reshape as there is only 1 time "t".
    S_net = U[:,0]
    I_net = U[:,1]
    R_net = U[:,2]
    
    # Calculate loss
    loss1 = torch_MSE_loss(S_net, S_data)
    loss2 = torch_MSE_loss(I_net, I_data)
    loss3 = torch_MSE_loss(R_net, R_data)
    
    loss_total = loss1 + loss2 + loss3
    
    return loss_total

# %%
# ================== Defining the network(s) ==================
class FFN(nn.Module):
    def __init__(self, input_size, hidden_layers_size, output_size):
        super(FFN, self).__init__()
        
        n_layers = len(hidden_layers_size)
        HL = hidden_layers_size
        
        # Define layers
        self.L1 = nn.Linear(input_size, HL[0])
        self.L2 = nn.Linear(HL[0], HL[1])
        self.L3 = nn.Linear(HL[1], HL[2])
        self.L4 = nn.Linear(HL[2], HL[3])
        self.output = nn.Linear(HL[-1], output_size)
        
        # Define activation function
        self.act_fn = nn.ReLU()

    def forward(self, x):
        # Hidden layers
        x = self.act_fn(self.L1(x))
        x = self.act_fn(self.L2(x))
        x = self.act_fn(self.L3(x))
        x = self.act_fn(self.L4(x))

        # Output layer
        x = self.output(x)
        
        return x

    
# Define network
net = FFN(1, [32,32,32,32], 3).to(my_device)

# Print Network shape
print()
print(net.parameters)
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Test the network
print(net(torch.tensor(1.0, device=my_device).view(-1,1)))
# Out:
# <bound method Module.parameters of FFN(
#   (L1): Linear(in_features=1, out_features=32, bias=True)
#   (L2): Linear(in_features=32, out_features=32, bias=True)
#   (L3): Linear(in_features=32, out_features=32, bias=True)
#   (L4): Linear(in_features=32, out_features=32, bias=True)
#   (output): Linear(in_features=32, out_features=3, bias=True)
#   (act_fn): ReLU()
# )>
# tensor([[-0.0268,  0.1592,  0.2338]], grad_fn=<AddmmBackward0>)

# %%
# ================== Testing the loss functions ==================
t_test = torch.linspace(0, 1000, 1001, device=my_device, requires_grad=True).view(-1,1)
t0 = torch.tensor([0.0], device=my_device)

# Converting initial conditions for torch formatting
S0 = torch.tensor([S0], device=my_device)
I0 = torch.tensor([I0], device=my_device)
R0 = torch.tensor([R0], device=my_device)
print(f'Initial Conditions: S0: {S0}, I0: {I0}, R0: {R0}')

# Testing ODE loss
loss_ODE = get_loss_ODE(net, t_test, alpha, beta)
print(loss_ODE)

# Testing IC loss
loss_IC = get_loss_IC(net, t0, S0, I0, R0)
print(loss_IC)

# Move data points to device
if has_been_run:
    t_data = torch.tensor(t, device=my_device, dtype=torch.float32)
    S_data = torch.tensor(S_data, device=my_device, dtype=torch.float32)
    I_data = torch.tensor(I_data, device=my_device, dtype=torch.float32)
    R_data = torch.tensor(R_data, device=my_device, dtype=torch.float32)
has_been_run = False
# Testing data loss
loss_data = get_data_point_loss(net, t_test, S_data, I_data, R_data)
print(loss_data)
# Out:
# Initial Conditions: S0: tensor([0.9000]), I0: tensor([0.1000]), R0: tensor([0.])
# tensor(0.0008, grad_fn=<AddBackward0>)
# tensor(0.9409, grad_fn=<AddBackward0>)
# tensor(12.6871, grad_fn=<AddBackward0>)

# %% [markdown]
# ### Training the network on the losses

# %%
# Loss saving
loss_saved, loss_ODE_saved, loss_IC_saved = [], [], []
#adapt_ode_loss_saved, adapt_IC_loss_saved = [], []
epochs_saved = [0]
# Setup optimizer
learning_rate = 1e-5
weight_decay = 0
optimizer = optim.Adam(net.parameters(), lr=learning_rate, weight_decay=weight_decay) #, weight_decay=1e-4

#setup softadapt
lambda_ode = torch.nn.Parameter(torch.tensor([1.0], requires_grad=True))
lambda_ic = torch.nn.Parameter(torch.tensor([1.0], requires_grad=True))
lambda_data = torch.nn.Parameter(torch.tensor([1.0], requires_grad=True))

lr_lambda = 3e-4
optimizer_ode = optim.Adam([lambda_ode], lr=lr_lambda)
optimizer_ic = optim.Adam([lambda_ic], lr=lr_lambda)
optimizer_data = optim.Adam([lambda_data], lr=lr_lambda)

# %%
## With sequential learning

# Training setup
num_epochs = 10000
save_every_epochs = 100

# Define the number of slices for the sequential learning sampling frequency
n_sequences = 5

# Define sampling points
data_samples = torch.arange(1, n_days, 100, device=my_device, dtype=torch.float32, requires_grad=True).view(-1,1)

# Calculate the size of each slice
slice_size = t.size // n_sequences
last_slice_size = int(t.size - slice_size * (n_sequences - 1))

# create time tensor
t_tensor = torch.arange(0, n_days, 1, device=my_device, dtype=torch.float32, requires_grad=True).view(-1,1)

losses, ode_losses, ic_losses, data_losses = [], [], [], []

net = net.to(my_device)

# Initialize variables to track the lowest loss and best model state
lowest_loss = float('inf')
best_model_state = None

# start a new wandb run to track this script
if wandb_on:
    wandb.init(
        # set the wandb project where this run will be logged
        project="SIR_PINN_test",

        # track hyperparameters and run metadata
        config={
        "learning_rate": learning_rate,
        "architecture": "FFNN (4*32)",
        "activation function" : "ReLU",
        "Weight decay": weight_decay,
        "epochs": num_epochs,
        "ODE loss": "yes",
        "IC loss": "yes",
        "Data points": "true",
        "Seq learn": "true"
        }
    )

# Track gradients in wandb
if wandb_on:
    wandb.watch(net, log_freq=10)

# Train model with sequential learning
for epoch in range(num_epochs):
    # Forward -> Backprob -> Update params
    ## Train
    cur_loss, ode_loss, ic_loss, data_loss = 0, 0, 0, 0
    net.train()
    
    for slice_num in range(n_sequences):
        # Determine the range of this slice
        start_idx = slice_num * slice_size
        if slice_num == n_sequences - 1:  # Last slice
            end_idx = start_idx + last_slice_size
        else:
            end_idx = start_idx + slice_size
        
        t_samples = t_tensor[start_idx:end_idx]
            
        optimizer.zero_grad()
        optimizer_ode.zero_grad()
        optimizer_ic.zero_grad()
        optimizer_data.zero_grad()

        #output = net(t_samples)
        
        # Find indices in t_data that fall within t_range
        #valid_indices = np.where((t_data >= t_samples[0]) & (t_data <= t_samples[-1]))[0]
        
        # Sample from these indices according to sample_frequency
        #sampled_indices = valid_indices[::sample_frequency]
        
        t_data_batch = torch.tensor([x for x in data_samples if x in t_samples],
                            device=data_samples.device, dtype=data_samples.dtype).numpy()
        
        # Calculate loss
        batch_loss_ode = get_loss_ODE(net, t_samples, alpha, beta)
        batch_loss_ic = get_loss_IC(net, t0, S0, I0, R0)
        batch_loss_data = get_data_point_loss(net, t_data[t_data_batch], S_data[t_data_batch], I_data[t_data_batch], R_data[t_data_batch])
        
        batch_loss = lambda_ode * batch_loss_ode + lambda_ic * batch_loss_ic + lambda_data * batch_loss_data
        
        batch_loss.backward()
    
            
        #maximize gradients of lambdas by inverting the gradient
        with torch.no_grad():
            lambda_ode.grad *= -1
            lambda_ic.grad *= -1
            lambda_data.grad *= -1
            
        optimizer.step()
        optimizer_ode.step()
        optimizer_ic.step()
        optimizer_data.step()
        
        cur_loss += batch_loss.detach().numpy()
        ode_loss += batch_loss_ode.detach().numpy()
        ic_loss += batch_loss_ic.detach().numpy()
        data_loss += batch_loss_data.detach().numpy()
        
         # Update loss tracking
        epoch_loss = cur_loss
        if epoch_loss < lowest_loss:
            lowest_loss = epoch_loss
            best_model_state = net.state_dict().copy()  # Save the best model state

        
    # log metrics to wandb
    if wandb_on:
        wandb.log({"loss": cur_loss, "ode_loss": ode_loss, "ic_loss": ic_loss, "data_loss": data_loss})
        
    losses.append(cur_loss)
    ode_losses.append(ode_loss)
    ic_losses.append(ic_loss)
    data_losses.append(data_loss)

    net.eval()
    
    if (epoch+1) % save_every_epochs == 0 or epoch == 0:
        print(f"Epoch {epoch+1:5}, Loss: {losses[-1].item():9.5f}, ode_loss: {ode_losses[-1].item():7.7f}, ic_loss: {ic_losses[-1].item():7.7f}, data_loss: {data_losses[-1].item():7.7f}"
                f", aw_ode: {lambda_ode.item():3.2f}, aw_ic: {lambda_ic.item():3.2f}, aw_data: {lambda_data.item():3.2f}")
        
# After training, load the best model state
net.load_state_dict(best_model_state)
# Out:
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>C:\Users\max44\OneDrive\GitHub\PINN-Project-02456\Notebooks\wandb\run-20231206_232654-r4aw2a9z</code>
# Syncing run <strong><a href='https://wandb.ai/dl_pinn/SIR_PINN_test/runs/r4aw2a9z' target="_blank">upbeat-thunder-32</a></strong> to <a href='https://wandb.ai/dl_pinn/SIR_PINN_test' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dl_pinn/SIR_PINN_test' target="_blank">https://wandb.ai/dl_pinn/SIR_PINN_test</a>
#  View run at <a href='https://wandb.ai/dl_pinn/SIR_PINN_test/runs/r4aw2a9z' target="_blank">https://wandb.ai/dl_pinn/SIR_PINN_test/runs/r4aw2a9z</a>
# Epoch     1, Loss:  58.44574, ode_loss: 0.0037009, ic_loss: 4.7015643, data_loss: 53.6914240, aw_ode: 1.00, aw_ic: 1.00, aw_data: 1.00
# Epoch   100, Loss:   5.51277, ode_loss: 0.0000288, ic_loss: 4.1501857, data_loss: 0.7326113, aw_ode: 1.01, aw_ic: 1.15, aw_data: 1.04
# Epoch   200, Loss:   5.33376, ode_loss: 0.0000263, ic_loss: 3.6197208, data_loss: 0.6604713, aw_ode: 1.02, aw_ic: 1.28, aw_data: 1.04
# Epoch   300, Loss:   4.90847, ode_loss: 0.0000314, ic_loss: 3.0226167, data_loss: 0.6094346, aw_ode: 1.03, aw_ic: 1.41, aw_data: 1.05
# Epoch   400, Loss:   4.25853, ode_loss: 0.0000444, ic_loss: 2.4014619, data_loss: 0.5534415, aw_ode: 1.05, aw_ic: 1.53, aw_data: 1.07
# Epoch   500, Loss:   3.52380, ode_loss: 0.0000844, ic_loss: 1.8423750, data_loss: 0.4785540, aw_ode: 1.08, aw_ic: 1.63, aw_data: 1.08
# Epoch   600, Loss:   2.60351, ode_loss: 0.0001559, ic_loss: 1.2696117, data_loss: 0.3811603, aw_ode: 1.14, aw_ic: 1.72, aw_data: 1.09
# Epoch   700, Loss:   1.72340, ode_loss: 0.0002470, ic_loss: 0.7626653, data_loss: 0.3211259, aw_ode: 1.24, aw_ic: 1.79, aw_data: 1.11
# Epoch   800, Loss:   0.98510, ode_loss: 0.0003789, ic_loss: 0.3750577, data_loss: 0.2614321, aw_ode: 1.35, aw_ic: 1.84, aw_data: 1.13
# Epoch   900, Loss:   0.50505, ode_loss: 0.0005753, ic_loss: 0.1373575, data_loss: 0.2167059, aw_ode: 1.46, aw_ic: 1.87, aw_data: 1.14
# Epoch  1000, Loss:   0.28226, ode_loss: 0.0007236, ic_loss: 0.0310500, data_loss: 0.1917163, aw_ode: 1.56, aw_ic: 1.88, aw_data: 1.16
# Epoch  1100, Loss:   0.18307, ode_loss: 0.0008085, ic_loss: 0.0029847, data_loss: 0.1488914, aw_ode: 1.65, aw_ic: 1.88, aw_data: 1.18
# Epoch  1200, Loss:   0.17271, ode_loss: 0.0007587, ic_loss: 0.0001732, data_loss: 0.1419743, aw_ode: 1.73, aw_ic: 1.88, aw_data: 1.21
# Epoch  1300, Loss:   0.17145, ode_loss: 0.0007452, ic_loss: 0.0003461, data_loss: 0.1375502, aw_ode: 1.80, aw_ic: 1.88, aw_data: 1.23
# Epoch  1400, Loss:   0.17085, ode_loss: 0.0007296, ic_loss: 0.0003785, data_loss: 0.1334134, aw_ode: 1.87, aw_ic: 1.88, aw_data: 1.27
# Epoch  1500, Loss:   0.17044, ode_loss: 0.0006874, ic_loss: 0.0003781, data_loss: 0.1290089, aw_ode: 1.94, aw_ic: 1.88, aw_data: 1.31
# Epoch  1600, Loss:   0.17098, ode_loss: 0.0006632, ic_loss: 0.0004507, data_loss: 0.1247109, aw_ode: 2.00, aw_ic: 1.88, aw_data: 1.35
# Epoch  1700, Loss:   0.16970, ode_loss: 0.0006159, ic_loss: 0.0004624, data_loss: 0.1187719, aw_ode: 2.06, aw_ic: 1.88, aw_data: 1.41
# Epoch  1800, Loss:   0.17092, ode_loss: 0.0005855, ic_loss: 0.0004433, data_loss: 0.1143481, aw_ode: 2.13, aw_ic: 1.88, aw_data: 1.48
# Epoch  1900, Loss:   0.16008, ode_loss: 0.0005371, ic_loss: 0.0004519, data_loss: 0.1019271, aw_ode: 2.19, aw_ic: 1.88, aw_data: 1.55
# Epoch  2000, Loss:   0.16129, ode_loss: 0.0004841, ic_loss: 0.0003965, data_loss: 0.0978413, aw_ode: 2.24, aw_ic: 1.88, aw_data: 1.63
# Epoch  2100, Loss:   0.16326, ode_loss: 0.0004435, ic_loss: 0.0003769, data_loss: 0.0940184, aw_ode: 2.30, aw_ic: 1.88, aw_data: 1.72
# Epoch  2200, Loss:   0.16537, ode_loss: 0.0003769, ic_loss: 0.0003345, data_loss: 0.0902894, aw_ode: 2.35, aw_ic: 1.88, aw_data: 1.82
# Epoch  2300, Loss:   0.16733, ode_loss: 0.0003541, ic_loss: 0.0002827, data_loss: 0.0865085, aw_ode: 2.41, aw_ic: 1.89, aw_data: 1.92
# Epoch  2400, Loss:   0.16242, ode_loss: 0.0003126, ic_loss: 0.0002289, data_loss: 0.0796511, aw_ode: 2.46, aw_ic: 1.89, aw_data: 2.02
# Epoch  2500, Loss:   0.16374, ode_loss: 0.0002919, ic_loss: 0.0001891, data_loss: 0.0762073, aw_ode: 2.52, aw_ic: 1.89, aw_data: 2.13
# Epoch  2600, Loss:   0.16392, ode_loss: 0.0002091, ic_loss: 0.0001759, data_loss: 0.0725466, aw_ode: 2.57, aw_ic: 1.89, aw_data: 2.25
# Epoch  2700, Loss:   0.16541, ode_loss: 0.0002241, ic_loss: 0.0001499, data_loss: 0.0696324, aw_ode: 2.61, aw_ic: 1.89, aw_data: 2.36
# Epoch  2800, Loss:   0.16678, ode_loss: 0.0001502, ic_loss: 0.0001220, data_loss: 0.0669978, aw_ode: 2.66, aw_ic: 1.89, aw_data: 2.48
# Epoch  2900, Loss:   0.16813, ode_loss: 0.0001190, ic_loss: 0.0000947, data_loss: 0.0645298, aw_ode: 2.71, aw_ic: 1.90, aw_data: 2.60
# Epoch  3000, Loss:   0.16906, ode_loss: 0.0000997, ic_loss: 0.0000685, data_loss: 0.0621016, aw_ode: 2.75, aw_ic: 1.90, aw_data: 2.72
# Epoch  3100, Loss:   0.17045, ode_loss: 0.0001764, ic_loss: 0.0000466, data_loss: 0.0599498, aw_ode: 2.80, aw_ic: 1.90, aw_data: 2.83
# Epoch  3200, Loss:   0.17118, ode_loss: 0.0000583, ic_loss: 0.0000288, data_loss: 0.0579333, aw_ode: 2.84, aw_ic: 1.90, aw_data: 2.95
# Epoch  3300, Loss:   0.16980, ode_loss: 0.0000503, ic_loss: 0.0000148, data_loss: 0.0553032, aw_ode: 2.89, aw_ic: 1.90, aw_data: 3.07
# Epoch  3400, Loss:   0.17085, ode_loss: 0.0000513, ic_loss: 0.0000072, data_loss: 0.0536307, aw_ode: 2.93, aw_ic: 1.90, aw_data: 3.18
# Epoch  3500, Loss:   0.17193, ode_loss: 0.0000743, ic_loss: 0.0000033, data_loss: 0.0520564, aw_ode: 2.96, aw_ic: 1.90, aw_data: 3.30
# Epoch  3600, Loss:   0.17268, ode_loss: 0.0000432, ic_loss: 0.0000020, data_loss: 0.0505409, aw_ode: 3.00, aw_ic: 1.90, aw_data: 3.41
# Epoch  3700, Loss:   0.17245, ode_loss: 0.0000422, ic_loss: 0.0000015, data_loss: 0.0488257, aw_ode: 3.04, aw_ic: 1.90, aw_data: 3.53
# Epoch  3800, Loss:   0.17282, ode_loss: 0.0000417, ic_loss: 0.0000013, data_loss: 0.0473924, aw_ode: 3.09, aw_ic: 1.90, aw_data: 3.64
# Epoch  3900, Loss:   0.17195, ode_loss: 0.0000437, ic_loss: 0.0000014, data_loss: 0.0457220, aw_ode: 3.14, aw_ic: 1.90, aw_data: 3.76
# Epoch  4000, Loss:   0.17151, ode_loss: 0.0000429, ic_loss: 0.0000015, data_loss: 0.0442700, aw_ode: 3.20, aw_ic: 1.90, aw_data: 3.87
# Epoch  4100, Loss:   0.16988, ode_loss: 0.0000428, ic_loss: 0.0000017, data_loss: 0.0426121, aw_ode: 3.27, aw_ic: 1.90, aw_data: 3.98
# Epoch  4200, Loss:   0.16858, ode_loss: 0.0000388, ic_loss: 0.0000022, data_loss: 0.0411388, aw_ode: 3.33, aw_ic: 1.90, aw_data: 4.10
# Epoch  4300, Loss:   0.16661, ode_loss: 0.0000419, ic_loss: 0.0000024, data_loss: 0.0395874, aw_ode: 3.40, aw_ic: 1.91, aw_data: 4.21
# Epoch  4400, Loss:   0.16469, ode_loss: 0.0000418, ic_loss: 0.0000026, data_loss: 0.0381374, aw_ode: 3.47, aw_ic: 1.91, aw_data: 4.31
# Epoch  4500, Loss:   0.16224, ode_loss: 0.0000415, ic_loss: 0.0000025, data_loss: 0.0366469, aw_ode: 3.54, aw_ic: 1.91, aw_data: 4.42
# Epoch  4600, Loss:   0.15994, ode_loss: 0.0000382, ic_loss: 0.0000029, data_loss: 0.0352696, aw_ode: 3.61, aw_ic: 1.91, aw_data: 4.53
# Epoch  4700, Loss:   0.15717, ode_loss: 0.0000596, ic_loss: 0.0000029, data_loss: 0.0338433, aw_ode: 3.70, aw_ic: 1.92, aw_data: 4.64
# Epoch  4800, Loss:   0.15457, ode_loss: 0.0000558, ic_loss: 0.0000031, data_loss: 0.0325425, aw_ode: 3.78, aw_ic: 1.92, aw_data: 4.74
# Epoch  4900, Loss:   0.15115, ode_loss: 0.0000655, ic_loss: 0.0000025, data_loss: 0.0311239, aw_ode: 3.86, aw_ic: 1.93, aw_data: 4.85
# Epoch  5000, Loss:   0.14785, ode_loss: 0.0000505, ic_loss: 0.0000025, data_loss: 0.0298157, aw_ode: 3.94, aw_ic: 1.94, aw_data: 4.95
# Epoch  5100, Loss:   0.14472, ode_loss: 0.0000576, ic_loss: 0.0000029, data_loss: 0.0285822, aw_ode: 4.01, aw_ic: 1.95, aw_data: 5.06
# Epoch  5200, Loss:   0.14106, ode_loss: 0.0000624, ic_loss: 0.0000026, data_loss: 0.0273007, aw_ode: 4.08, aw_ic: 1.96, aw_data: 5.16
# Epoch  5300, Loss:   0.13794, ode_loss: 0.0000964, ic_loss: 0.0000027, data_loss: 0.0261510, aw_ode: 4.17, aw_ic: 1.98, aw_data: 5.26
# Epoch  5400, Loss:   0.13455, ode_loss: 0.0000950, ic_loss: 0.0000024, data_loss: 0.0250248, aw_ode: 4.26, aw_ic: 2.00, aw_data: 5.36
# Epoch  5500, Loss:   0.13100, ode_loss: 0.0000947, ic_loss: 0.0000021, data_loss: 0.0239114, aw_ode: 4.34, aw_ic: 2.02, aw_data: 5.46
# Epoch  5600, Loss:   0.12784, ode_loss: 0.0000979, ic_loss: 0.0000013, data_loss: 0.0229084, aw_ode: 4.42, aw_ic: 2.05, aw_data: 5.56
# Epoch  5700, Loss:   0.12468, ode_loss: 0.0000986, ic_loss: 0.0000010, data_loss: 0.0219456, aw_ode: 4.49, aw_ic: 2.07, aw_data: 5.66
# Epoch  5800, Loss:   0.12245, ode_loss: 0.0000964, ic_loss: 0.0000008, data_loss: 0.0211774, aw_ode: 4.56, aw_ic: 2.09, aw_data: 5.76
# Epoch  5900, Loss:   0.11829, ode_loss: 0.0000934, ic_loss: 0.0000003, data_loss: 0.0201087, aw_ode: 4.63, aw_ic: 2.10, aw_data: 5.86
# Epoch  6000, Loss:   0.11467, ode_loss: 0.0000821, ic_loss: 0.0000002, data_loss: 0.0191731, aw_ode: 4.69, aw_ic: 2.12, aw_data: 5.96
# Epoch  6100, Loss:   0.11154, ode_loss: 0.0000797, ic_loss: 0.0000003, data_loss: 0.0183419, aw_ode: 4.76, aw_ic: 2.13, aw_data: 6.06
# Epoch  6200, Loss:   0.10845, ode_loss: 0.0000709, ic_loss: 0.0000001, data_loss: 0.0175504, aw_ode: 4.82, aw_ic: 2.14, aw_data: 6.16
# Epoch  6300, Loss:   0.10489, ode_loss: 0.0000670, ic_loss: 0.0000001, data_loss: 0.0167042, aw_ode: 4.88, aw_ic: 2.15, aw_data: 6.26
# Epoch  6400, Loss:   0.10357, ode_loss: 0.0000573, ic_loss: 0.0000001, data_loss: 0.0162404, aw_ode: 4.94, aw_ic: 2.17, aw_data: 6.36
# Epoch  6500, Loss:   0.09816, ode_loss: 0.0000580, ic_loss: 0.0000005, data_loss: 0.0151506, aw_ode: 5.00, aw_ic: 2.18, aw_data: 6.46
# Epoch  6600, Loss:   0.09346, ode_loss: 0.0000521, ic_loss: 0.0000001, data_loss: 0.0142099, aw_ode: 5.05, aw_ic: 2.20, aw_data: 6.56
# Epoch  6700, Loss:   0.09025, ode_loss: 0.0000500, ic_loss: 0.0000001, data_loss: 0.0135175, aw_ode: 5.11, aw_ic: 2.22, aw_data: 6.66
# Epoch  6800, Loss:   0.08643, ode_loss: 0.0000463, ic_loss: 0.0000000, data_loss: 0.0127566, aw_ode: 5.17, aw_ic: 2.24, aw_data: 6.76
# Epoch  6900, Loss:   0.08327, ode_loss: 0.0000385, ic_loss: 0.0000000, data_loss: 0.0121152, aw_ode: 5.23, aw_ic: 2.26, aw_data: 6.86
# Epoch  7000, Loss:   0.08179, ode_loss: 0.0000400, ic_loss: 0.0000001, data_loss: 0.0117258, aw_ode: 5.29, aw_ic: 2.29, aw_data: 6.96
# Epoch  7100, Loss:   0.07594, ode_loss: 0.0000355, ic_loss: 0.0000001, data_loss: 0.0107358, aw_ode: 5.34, aw_ic: 2.32, aw_data: 7.06
# Epoch  7200, Loss:   0.07241, ode_loss: 0.0000353, ic_loss: 0.0000001, data_loss: 0.0100936, aw_ode: 5.40, aw_ic: 2.36, aw_data: 7.16
# Epoch  7300, Loss:   0.06902, ode_loss: 0.0000333, ic_loss: 0.0000000, data_loss: 0.0094883, aw_ode: 5.47, aw_ic: 2.40, aw_data: 7.26
# Epoch  7400, Loss:   0.06564, ode_loss: 0.0000330, ic_loss: 0.0000001, data_loss: 0.0088998, aw_ode: 5.53, aw_ic: 2.46, aw_data: 7.36
# Epoch  7500, Loss:   0.06266, ode_loss: 0.0000289, ic_loss: 0.0000001, data_loss: 0.0083837, aw_ode: 5.59, aw_ic: 2.50, aw_data: 7.46
# Epoch  7600, Loss:   0.05909, ode_loss: 0.0000292, ic_loss: 0.0000000, data_loss: 0.0077990, aw_ode: 5.66, aw_ic: 2.57, aw_data: 7.56
# Epoch  7700, Loss:   0.05603, ode_loss: 0.0000257, ic_loss: 0.0000000, data_loss: 0.0073002, aw_ode: 5.72, aw_ic: 2.64, aw_data: 7.66
# Epoch  7800, Loss:   0.05300, ode_loss: 0.0000244, ic_loss: 0.0000000, data_loss: 0.0068156, aw_ode: 5.78, aw_ic: 2.71, aw_data: 7.76
# Epoch  7900, Loss:   0.04943, ode_loss: 0.0000232, ic_loss: 0.0000000, data_loss: 0.0062754, aw_ode: 5.85, aw_ic: 2.78, aw_data: 7.86
# Epoch  8000, Loss:   0.04631, ode_loss: 0.0000208, ic_loss: 0.0000000, data_loss: 0.0058060, aw_ode: 5.91, aw_ic: 2.84, aw_data: 7.96
# Epoch  8100, Loss:   0.04314, ode_loss: 0.0000189, ic_loss: 0.0000000, data_loss: 0.0053416, aw_ode: 5.98, aw_ic: 2.90, aw_data: 8.06
# Epoch  8200, Loss:   0.04046, ode_loss: 0.0000202, ic_loss: 0.0000000, data_loss: 0.0049491, aw_ode: 6.04, aw_ic: 2.94, aw_data: 8.15
# Epoch  8300, Loss:   0.03760, ode_loss: 0.0000189, ic_loss: 0.0000000, data_loss: 0.0045437, aw_ode: 6.10, aw_ic: 3.00, aw_data: 8.25
# Epoch  8400, Loss:   0.03517, ode_loss: 0.0000173, ic_loss: 0.0000000, data_loss: 0.0041985, aw_ode: 6.16, aw_ic: 3.06, aw_data: 8.35
# Epoch  8500, Loss:   0.03252, ode_loss: 0.0000166, ic_loss: 0.0000000, data_loss: 0.0038364, aw_ode: 6.22, aw_ic: 3.11, aw_data: 8.45
# Epoch  8600, Loss:   0.03046, ode_loss: 0.0000148, ic_loss: 0.0000000, data_loss: 0.0035519, aw_ode: 6.29, aw_ic: 3.18, aw_data: 8.55
# Epoch  8700, Loss:   0.03086, ode_loss: 0.0000146, ic_loss: 0.0000001, data_loss: 0.0035603, aw_ode: 6.35, aw_ic: 3.22, aw_data: 8.64
# Epoch  8800, Loss:   0.02806, ode_loss: 0.0000164, ic_loss: 0.0000001, data_loss: 0.0031958, aw_ode: 6.42, aw_ic: 3.30, aw_data: 8.75
# Epoch  8900, Loss:   0.02549, ode_loss: 0.0000155, ic_loss: 0.0000001, data_loss: 0.0028724, aw_ode: 6.49, aw_ic: 3.35, aw_data: 8.84
# Epoch  9000, Loss:   0.02726, ode_loss: 0.0000144, ic_loss: 0.0000001, data_loss: 0.0030402, aw_ode: 6.56, aw_ic: 3.42, aw_data: 8.94
# Epoch  9100, Loss:   0.02701, ode_loss: 0.0000138, ic_loss: 0.0000000, data_loss: 0.0029797, aw_ode: 6.63, aw_ic: 3.47, aw_data: 9.04
# Epoch  9200, Loss:   0.02432, ode_loss: 0.0000131, ic_loss: 0.0000000, data_loss: 0.0026537, aw_ode: 6.69, aw_ic: 3.53, aw_data: 9.13
# Epoch  9300, Loss:   0.01816, ode_loss: 0.0000124, ic_loss: 0.0000001, data_loss: 0.0019590, aw_ode: 6.76, aw_ic: 3.60, aw_data: 9.23
# Epoch  9400, Loss:   0.03074, ode_loss: 0.0000119, ic_loss: 0.0000005, data_loss: 0.0032893, aw_ode: 6.82, aw_ic: 3.66, aw_data: 9.32
# Epoch  9500, Loss:   0.03002, ode_loss: 0.0000116, ic_loss: 0.0000003, data_loss: 0.0031792, aw_ode: 6.89, aw_ic: 3.73, aw_data: 9.42
# Epoch  9600, Loss:   0.01519, ode_loss: 0.0000114, ic_loss: 0.0000000, data_loss: 0.0015889, aw_ode: 6.96, aw_ic: 3.79, aw_data: 9.51
# Epoch  9700, Loss:   0.01886, ode_loss: 0.0000104, ic_loss: 0.0000003, data_loss: 0.0019555, aw_ode: 7.02, aw_ic: 3.87, aw_data: 9.61
# Epoch  9800, Loss:   0.01476, ode_loss: 0.0000102, ic_loss: 0.0000000, data_loss: 0.0015148, aw_ode: 7.09, aw_ic: 3.92, aw_data: 9.69
# Epoch  9900, Loss:   0.01732, ode_loss: 0.0000100, ic_loss: 0.0000002, data_loss: 0.0017633, aw_ode: 7.16, aw_ic: 3.99, aw_data: 9.78
# Epoch 10000, Loss:   0.01701, ode_loss: 0.0000097, ic_loss: 0.0000000, data_loss: 0.0017150, aw_ode: 7.22, aw_ic: 4.07, aw_data: 9.88
# <All keys matched successfully>

# %%
# finish the wandb run
if wandb_on:
    wandb.finish()
# Out:
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>data_loss</td><td>█▇▅▄▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>ic_loss</td><td>█▇▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss</td><td>██▅▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>ode_loss</td><td>▁▁▂▄██▇▆▅▄▄▂▃▁▁▁▁▁▁▁▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>data_loss</td><td>0.00171</td></tr><tr><td>ic_loss</td><td>0.0</td></tr><tr><td>loss</td><td>0.01701</td></tr><tr><td>ode_loss</td><td>1e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">upbeat-thunder-32</strong> at: <a href='https://wandb.ai/dl_pinn/SIR_PINN_test/runs/r4aw2a9z' target="_blank">https://wandb.ai/dl_pinn/SIR_PINN_test/runs/r4aw2a9z</a><br/> View job at <a href='https://wandb.ai/dl_pinn/SIR_PINN_test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEyMTQ0NTY5OA==/version_details/v1' target="_blank">https://wandb.ai/dl_pinn/SIR_PINN_test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEyMTQ0NTY5OA==/version_details/v1</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231206_232654-r4aw2a9z\logs</code>

# %%
print(net(t0))
# Out:
# tensor([9.0000e-01, 9.9996e-02, 4.4614e-05], grad_fn=<AddBackward0>)

# %%
fig, ax = plt.subplots(1,1)
ax.plot(losses, label='loss')
ax.plot(ode_losses, label='ODE loss')
ax.plot(ic_losses, label='IC loss')
ax.legend()

# %%
net_cpu = net.to('cpu')

U = net_cpu(torch.tensor(t).float().view(-1,1))
S_net = U[:,0]
I_net = U[:,1]
R_net = U[:,2]

# Plot numerical solution
fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.plot(t, S_net.detach().numpy(), linestyle='-', label='S_net', color='blue')
ax.plot(t, I_net.detach().numpy(), linestyle='-', label='I_net', color='red')
ax.plot(t, R_net.detach().numpy(), linestyle='-', label='R_net', color='green')
ax.plot(t, S_data.clone().to('cpu'), linestyle='--', label='S_num', color='blue')
ax.plot(t, I_data.clone().to('cpu'), linestyle='--', label='I_num', color='red')
ax.plot(t, R_data.clone().to('cpu'), linestyle='--', label='R_num', color='green')

ax.set_xlabel('Time [days]')
ax.set_ylabel('S(t), I(t), R(t) [Count]')
ax.legend() 
ax.set_title('Numerical Solution to SIR model')
# Out:
# Text(0.5, 1.0, 'Numerical Solution to SIR model')

# %%
# check stuff using numpy and gradient
S_net_np = S_net.detach().numpy()
I_net_np = I_net.detach().numpy()
R_net_np = R_net.detach().numpy()

# Running the sdfh nioa
dSdt = np.gradient(S_net_np)
dIdt = np.gradient(I_net_np)
dRdt = np.gradient(R_net_np)

rhs_S = beta * S_net_np * I_net_np
rhs_I = -beta * S_net_np * I_net_np + alpha * I_net_np
rhs_R = -alpha * I_net_np

# %%
fig, ax = plt.subplots(1,1)
ax.plot(dSdt, color='blue', linestyle='-', label='dSdt')
ax.plot(rhs_S, color='blue', linestyle='--', label='rhs_S')
ax.plot(dIdt, color='red', linestyle='-', label='dSdt')
ax.plot(rhs_I, color='red', linestyle='--', label='rhs_S')
ax.plot(dRdt, color='green', linestyle='-', label='dSdt')
ax.plot(rhs_R, color='green', linestyle='--', label='rhs_S')
ax.set_ylim(-0.01, 0.01)
ax.legend()

# %%
t_data_batch
# Out:
# array([801., 901.], dtype=float32)
