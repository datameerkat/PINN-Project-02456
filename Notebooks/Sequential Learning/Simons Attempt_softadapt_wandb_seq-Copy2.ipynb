# %% [markdown]
# # SIR modelling as in: Data-driven approaches for predicting spread of infectious diseases through DINNs: Disease Informed Neural Networks
#
# Notes for self:
# SIR stands for
# - Susceptible
# - Infective
# - Removed (recovered)
#
# S -> I -> R
# The transfer rate from S->I is beta. Called transmission rate.
# The transfer rate from I->R is alpha. Called recovery rate.
#
# The system of ODE with the 3 variables is as follows. All variables are functions of time t:
# dS/dt = -beta * S * I
# dI/dt = beta * S * I - alpha * I
# dR/dt = alpha I
#
# Assumed that no one has recovered at the onset:
# R(0) = 0
# Initial number of Infected is I(0) = I_0
#
# ## How DINN's are trained
# 1. The ODE's are solved with known initial conditions and true parameters (I think they mean alpha, beta etc.).
#     This step results in a data series of S, I, R for each t. They use 50-100 points.
#     They restrict the parameters around the true values. Not stated by how much.
# 2. For this set of data points we train using loss from
#     - Data point loss
#     - ODE loss
#
# Note: I am a unsure how they obtain the parameters alpha beta from the network. They train the network to take in a time t and
# output a S, I, R. How does this result in an alpha/beta etc.

# %%
from scipy.integrate import solve_ivp
import torch
from torch import nn
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

from torch.nn.parameter import Parameter
#from torchvision.datasets import MNIST
from timeit import default_timer as tdt

import wandb

#from softadapt import SoftAdapt, NormalizedSoftAdapt, LossWeightedSoftAdapt

if torch.cuda.is_available():
    my_device = 'cuda'
else:
    my_device = 'cpu'
    
has_been_run = True

wandb_on = False

# %%
# login in Weights&Biases
if wandb_on:
    wandb.login()

# %%
# Time setup
n_days = 1000
t = np.arange(0, n_days+1, 1)

## Disease setup
alpha = 0.01
beta = 0.025

# Initial conditions
N = 1000.0   # Population size
I0 = 100.0/N      # Initial number of infected
R0 = 0.0/N      # Initial number of recovered
S0 = 1 - I0 - R0    # Initial number of susceptible

# %% [markdown]
# # Solving the system numerically

# %%
# Solve numerically
def SIR_model_num(t, y, N, beta, alpha):
    S, I, R = y
    dSdt = -beta * S * I
    dIdt = beta * S * I - alpha * I
    dRdt = alpha * I
    return [dSdt, dIdt, dRdt]

# Setup initial conditions 
y0 = [S0, I0, R0]

# Solve using LSODA method from scipy
sol = solve_ivp(SIR_model_num, [t[0], t[-1]], y0, args=(N/N, beta, alpha), t_eval=t, method='LSODA')

S_data = sol.y[0]
I_data = sol.y[1]
R_data = sol.y[2]
print(sol.message)
# Out:
# The solver successfully reached the end of the integration interval.

# %%
# Plot numerical solution
fig, ax = plt.subplots(1, 1, figsize=(8,2))
ax.plot(t, S_data, linestyle='--', label='S')
ax.plot(t, I_data, linestyle='--', label='I')
ax.plot(t, R_data, linestyle='--', label='R')

ax.set_xlabel('Time [days]')
ax.set_ylabel('S(t), I(t), R(t) [Count]')
ax.legend()
ax.set_title('Numerical Solution to SIR model')
# Out:
# Text(0.5, 1.0, 'Numerical Solution to SIR model')

# %% [markdown]
# # Training a neural network to solve the ODE system
# In the following I will setup a network for solving the system of ODE's (SIR model).
# I will assume we know beta and alpha here which is of course cheating. The idea is to figure out what
# network size we need in order to capture the dynamics.
# ## Description
# ### Loss functions
# Two loss functions will be implemented at first
# 1. The ODE loss
# 2. The initial condition loss
# Later loss based on data points will be implemented
# ### Network structure
# The input for the network will be time t.
# The output of the network will be U.
# where
# S = U[0]
# I = U[1]
# R = U[2]

# %%
# ================== Loss functions ==================
# Defining loss function for reasons unknown
torch_MSE_loss = torch.nn.MSELoss()

# Loss for the ODE
def get_loss_ODE(net, t, alpha, beta):
    # Find network solution
    U = net(t)
    S = U[:,0]
    I = U[:,1]
    R = U[:,2]
    
    # Calculate derivatives
    dSdt = torch.autograd.grad(S, t, grad_outputs=torch.ones_like(S), create_graph=True)[0].squeeze()
    dIdt = torch.autograd.grad(I, t, grad_outputs=torch.ones_like(I), create_graph=True)[0].squeeze()
    dRdt = torch.autograd.grad(R, t, grad_outputs=torch.ones_like(R), create_graph=True)[0].squeeze()
    
    # Calculate loss
    # Error1:
    rhs_S = -beta * S * I
    loss1 = torch_MSE_loss(dSdt, rhs_S)
    # Error2:
    rhs_I = beta * S * I - alpha * I
    loss2 = torch_MSE_loss(dIdt, rhs_I)
    # Error3:
    rhs_R = alpha * I
    loss3 = torch_MSE_loss(dRdt, rhs_R)
    
    # Summing the loss. Consider returning all 3 and doing the adaptiveWeight loss on them.
    loss_total = loss1 + loss2 + loss3
    
    return loss_total

# Loss for the initial condition
def get_loss_IC(net, t0, S0, I0, R0):
    # Find network solution
    U = net(t0).view(1,-1)   # reshape as there is only 1 time "t".
    S0_net = U[:,0]
    I0_net = U[:,1]
    R0_net = U[:,2]
    
    # Calculate loss
    loss1 = torch_MSE_loss(S0, S0_net)
    loss2 = torch_MSE_loss(I0, I0_net)
    loss3 = torch_MSE_loss(R0, R0_net)
    
    # Summing the loss. Consider retutning all 3 and doing the adaptiveWeight loss on them.
    loss_total = loss1 + loss2 + loss3 
    
    return loss_total

def get_data_point_loss(net, t_data, S_data, I_data, R_data):
    # Find network solution
    U = net(t_data.view(-1,1))   # reshape as there is only 1 time "t".
    S_net = U[:,0]
    I_net = U[:,1]
    R_net = U[:,2]
    
    # Calculate loss
    loss1 = torch_MSE_loss(S_net, S_data)
    loss2 = torch_MSE_loss(I_net, I_data)
    loss3 = torch_MSE_loss(R_net, R_data)
    
    loss_total = loss1 + loss2 + loss3
    
    return loss_total

# %%
# ================== Defining the network(s) ==================
class FFN(nn.Module):
    def __init__(self, input_size, hidden_layers_size, output_size):
        super(FFN, self).__init__()
        
        n_layers = len(hidden_layers_size)
        HL = hidden_layers_size
        
        # Define layers
        self.L1 = nn.Linear(input_size, HL[0])
        self.L2 = nn.Linear(HL[0], HL[1])
        self.L3 = nn.Linear(HL[1], HL[2])
        self.L4 = nn.Linear(HL[2], HL[3])
        self.output = nn.Linear(HL[-1], output_size)
        
        # Define activation function
        self.act_fn = nn.ReLU()

    def forward(self, x):
        # Hidden layers
        x = self.act_fn(self.L1(x))
        x = self.act_fn(self.L2(x))
        x = self.act_fn(self.L3(x))
        x = self.act_fn(self.L4(x))

        # Output layer
        x = self.output(x)
        
        return x

    
# Define network
net = FFN(1, [32,32,32,32], 3).to(my_device)

# Print Network shape
print()
print(net.parameters)
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Test the network
print(net(torch.tensor(1.0, device=my_device).view(-1,1)))
# Out:
# <bound method Module.parameters of FFN(
#   (L1): Linear(in_features=1, out_features=32, bias=True)
#   (L2): Linear(in_features=32, out_features=32, bias=True)
#   (L3): Linear(in_features=32, out_features=32, bias=True)
#   (L4): Linear(in_features=32, out_features=32, bias=True)
#   (output): Linear(in_features=32, out_features=3, bias=True)
#   (act_fn): ReLU()
# )>
# tensor([[ 0.1072,  0.0092, -0.0272]], grad_fn=<AddmmBackward0>)

# %%
# ================== Testing the loss functions ==================
t_test = torch.linspace(0, 1000, 1001, device=my_device, requires_grad=True).view(-1,1)
t0 = torch.tensor([0.0], device=my_device)

# Converting initial conditions for torch formatting
S0 = torch.tensor([S0], device=my_device)
I0 = torch.tensor([I0], device=my_device)
R0 = torch.tensor([R0], device=my_device)
print(f'Initial Conditions: S0: {S0}, I0: {I0}, R0: {R0}')

# Testing ODE loss
loss_ODE = get_loss_ODE(net, t_test, alpha, beta)
print(loss_ODE)

# Testing IC loss
loss_IC = get_loss_IC(net, t0, S0, I0, R0)
print(loss_IC)

# Move data points to device
if has_been_run:
    t_data = torch.tensor(t, device=my_device, dtype=torch.float32)
    S_data = torch.tensor(S_data, device=my_device, dtype=torch.float32)
    I_data = torch.tensor(I_data, device=my_device, dtype=torch.float32)
    R_data = torch.tensor(R_data, device=my_device, dtype=torch.float32)
has_been_run = False
# Testing data loss
loss_data = get_data_point_loss(net, t_test, S_data, I_data, R_data)
print(loss_data)
# Out:
# Initial Conditions: S0: tensor([0.9000]), I0: tensor([0.1000]), R0: tensor([0.])
# tensor(0.1694, grad_fn=<AddBackward0>)
# tensor(0.6177, grad_fn=<AddBackward0>)
# tensor(48.5480, grad_fn=<AddBackward0>)

# %% [markdown]
# ### Training the network on the losses

# %%
# Loss saving
loss_saved, loss_ODE_saved, loss_IC_saved = [], [], []
#adapt_ode_loss_saved, adapt_IC_loss_saved = [], []
epochs_saved = [0]
# Setup optimizer
learning_rate = 1e-5
weight_decay = 0
optimizer = optim.Adam(net.parameters(), lr=learning_rate, weight_decay=weight_decay) #, weight_decay=1e-4

#setup softadapt
lambda_ode = torch.nn.Parameter(torch.tensor([1.0], requires_grad=True))
lambda_ic = torch.nn.Parameter(torch.tensor([1.0], requires_grad=True))
lambda_data = torch.nn.Parameter(torch.tensor([1.0], requires_grad=True))

lr_lambda = 3e-4
optimizer_ode = optim.Adam([lambda_ode], lr=lr_lambda)
optimizer_ic = optim.Adam([lambda_ic], lr=lr_lambda)
optimizer_data = optim.Adam([lambda_data], lr=lr_lambda)

# %%
## With sequential learning

# Training setup
num_epochs = 10000
save_every_epochs = 100

# Define the number of slices for the sequential learning sampling frequency
n_sequences = 10
sampling_frequency = 25

# Define sampling points
data_samples = torch.arange(1, 400, sampling_frequency, device=my_device, dtype=torch.float32, requires_grad=True).view(-1,1)

# Calculate the size of each slice
slice_size = t.size // n_sequences
last_slice_size = int(t.size - slice_size * (n_sequences - 1))

# create time tensor
t_tensor = torch.arange(0, n_days, 1, device=my_device, dtype=torch.float32, requires_grad=True).view(-1,1)

losses, ode_losses, ic_losses, data_losses = [], [], [], []

net = net.to(my_device)

# Initialize variables to track the lowest loss and best model state
lowest_loss = float('inf')
best_model_state = None

# start a new wandb run to track this script
if wandb_on:
    wandb.init(
        # set the wandb project where this run will be logged
        project="SIR_PINN_test",

        # track hyperparameters and run metadata
        config={
        "learning_rate": learning_rate,
        "architecture": "FFNN (4*32)",
        "activation function" : "ReLU",
        "Weight decay": weight_decay,
        "epochs": num_epochs,
        "ODE loss": "yes",
        "IC loss": "yes",
        "Data points": "true",
        "Seq learn": "true"
        }
    )

# Track gradients in wandb
if wandb_on:
    wandb.watch(net, log_freq=10)

# Train model with sequential learning
for epoch in range(num_epochs):
    # Forward -> Backprob -> Update params
    ## Train
    cur_loss, ode_loss, ic_loss, data_loss = 0, 0, 0, 0
    net.train()
    
    for slice_num in range(n_sequences):
        # Determine the range of this slice
        start_idx = slice_num * slice_size
        if slice_num == n_sequences - 1:  # Last slice
            end_idx = start_idx + last_slice_size
        else:
            end_idx = start_idx + slice_size
        
        t_samples = t_tensor[start_idx:end_idx]
            
        optimizer.zero_grad()
        optimizer_ode.zero_grad()
        optimizer_ic.zero_grad()
        optimizer_data.zero_grad()

        #output = net(t_samples)
        
        # Find indices in t_data that fall within t_range
        #valid_indices = np.where((t_data >= t_samples[0]) & (t_data <= t_samples[-1]))[0]
        
        # Sample from these indices according to sample_frequency
        #sampled_indices = valid_indices[::sample_frequency]
        
        t_data_batch = torch.tensor([x for x in data_samples if x in t_samples],
                            device=data_samples.device, dtype=data_samples.dtype).numpy()
        
        # Calculate loss
        batch_loss_ode = get_loss_ODE(net, t_samples, alpha, beta)
        batch_loss_ic = get_loss_IC(net, t0, S0, I0, R0)
        if t_data_batch.size != 0:
            batch_loss_data = get_data_point_loss(net, t_data[t_data_batch], S_data[t_data_batch], I_data[t_data_batch], R_data[t_data_batch])
        
        if t_data_batch.size != 0:
            batch_loss = lambda_ode * batch_loss_ode + lambda_ic * batch_loss_ic + lambda_data * batch_loss_data
        elif t_data_batch.size == 0:
            batch_loss = lambda_ode * batch_loss_ode + lambda_ic * batch_loss_ic
        
        batch_loss.backward()
    
            
        #maximize gradients of lambdas by inverting the gradient
        with torch.no_grad():
            lambda_ode.grad *= -1
            lambda_ic.grad *= -1
            lambda_data.grad *= -1
            
        optimizer.step()
        optimizer_ode.step()
        optimizer_ic.step()
        optimizer_data.step()
        
        cur_loss += batch_loss.detach().numpy()
        ode_loss += batch_loss_ode.detach().numpy()
        ic_loss += batch_loss_ic.detach().numpy()
        data_loss += batch_loss_data.detach().numpy()
        
         # Update loss tracking
        epoch_loss = cur_loss
        if epoch_loss < lowest_loss:
            lowest_loss = epoch_loss
            best_model_state = net.state_dict().copy()  # Save the best model state

        
    # log metrics to wandb
    if wandb_on:
        wandb.log({"loss": cur_loss, "ode_loss": ode_loss, "ic_loss": ic_loss, "data_loss": data_loss})
        
    losses.append(cur_loss)
    ode_losses.append(ode_loss)
    ic_losses.append(ic_loss)
    data_losses.append(data_loss)

    net.eval()
    
    if (epoch+1) % save_every_epochs == 0 or epoch == 0:
        print(f"Epoch {epoch+1:5}, Loss: {losses[-1].item():9.5f}, ode_loss: {ode_losses[-1].item():7.7f}, ic_loss: {ic_losses[-1].item():7.7f}, data_loss: {data_losses[-1].item():7.7f}"
                f", aw_ode: {lambda_ode.item():3.2f}, aw_ic: {lambda_ic.item():3.2f}, aw_data: {lambda_data.item():3.2f}")
        
# After training, load the best model state
net.load_state_dict(best_model_state)
# Out:
# Epoch     1, Loss:  38.86973, ode_loss: 1.4375003, ic_loss: 6.1686709, data_loss: 131.4170824, aw_ode: 1.00, aw_ic: 1.00, aw_data: 1.00
# Epoch   100, Loss:   7.84375, ode_loss: 0.0062362, ic_loss: 4.6477658, data_loss: 5.1320988, aw_ode: 1.03, aw_ic: 1.28, aw_data: 1.08
# Epoch   200, Loss:   5.32071, ode_loss: 0.0004756, ic_loss: 3.0947482, data_loss: 0.8104290, aw_ode: 1.03, aw_ic: 1.53, aw_data: 1.09
# Epoch   300, Loss:   3.18128, ode_loss: 0.0006241, ic_loss: 1.5604113, data_loss: 0.6757825, aw_ode: 1.03, aw_ic: 1.72, aw_data: 1.11
# Epoch   400, Loss:   1.03022, ode_loss: 0.0008313, ic_loss: 0.3408841, data_loss: 0.5448203, aw_ode: 1.04, aw_ic: 1.82, aw_data: 1.13
# Epoch   500, Loss:   0.32068, ode_loss: 0.0013171, ic_loss: 0.0135317, data_loss: 0.3773823, aw_ode: 1.04, aw_ic: 1.84, aw_data: 1.16
# Epoch   600, Loss:   0.26598, ode_loss: 0.0011364, ic_loss: 0.0000852, data_loss: 0.3327729, aw_ode: 1.06, aw_ic: 1.84, aw_data: 1.20
# Epoch   700, Loss:   0.25071, ode_loss: 0.0010489, ic_loss: 0.0001561, data_loss: 0.3008858, aw_ode: 1.08, aw_ic: 1.84, aw_data: 1.25
# Epoch   800, Loss:   0.22274, ode_loss: 0.0008832, ic_loss: 0.0000491, data_loss: 0.2563143, aw_ode: 1.11, aw_ic: 1.84, aw_data: 1.32
# Epoch   900, Loss:   0.19842, ode_loss: 0.0007215, ic_loss: 0.0000420, data_loss: 0.2168239, aw_ode: 1.14, aw_ic: 1.84, aw_data: 1.40
# Epoch  1000, Loss:   0.15155, ode_loss: 0.0005577, ic_loss: 0.0000202, data_loss: 0.1596117, aw_ode: 1.19, aw_ic: 1.84, aw_data: 1.48
# Epoch  1100, Loss:   0.12820, ode_loss: 0.0003764, ic_loss: 0.0000222, data_loss: 0.1310994, aw_ode: 1.24, aw_ic: 1.84, aw_data: 1.57
# Epoch  1200, Loss:   0.10539, ode_loss: 0.0003111, ic_loss: 0.0000134, data_loss: 0.1059187, aw_ode: 1.30, aw_ic: 1.84, aw_data: 1.66
# Epoch  1300, Loss:   0.07013, ode_loss: 0.0001906, ic_loss: 0.0000071, data_loss: 0.0717088, aw_ode: 1.37, aw_ic: 1.84, aw_data: 1.75
# Epoch  1400, Loss:   0.05025, ode_loss: 0.0001336, ic_loss: 0.0000015, data_loss: 0.0560684, aw_ode: 1.43, aw_ic: 1.84, aw_data: 1.84
# Epoch  1500, Loss:   0.03966, ode_loss: 0.0001113, ic_loss: 0.0000008, data_loss: 0.0521741, aw_ode: 1.50, aw_ic: 1.84, aw_data: 1.92
# Epoch  1600, Loss:   0.03587, ode_loss: 0.0000996, ic_loss: 0.0000011, data_loss: 0.0519332, aw_ode: 1.59, aw_ic: 1.84, aw_data: 2.02
# Epoch  1700, Loss:   0.03088, ode_loss: 0.0000876, ic_loss: 0.0000010, data_loss: 0.0426653, aw_ode: 1.71, aw_ic: 1.84, aw_data: 2.14
# Epoch  1800, Loss:   0.02816, ode_loss: 0.0000785, ic_loss: 0.0000009, data_loss: 0.0375108, aw_ode: 1.86, aw_ic: 1.84, aw_data: 2.28
# Epoch  1900, Loss:   0.03009, ode_loss: 0.0000796, ic_loss: 0.0000018, data_loss: 0.0395832, aw_ode: 2.03, aw_ic: 1.84, aw_data: 2.43
# Epoch  2000, Loss:   0.02890, ode_loss: 0.0000731, ic_loss: 0.0000014, data_loss: 0.0343981, aw_ode: 2.22, aw_ic: 1.84, aw_data: 2.59
# Epoch  2100, Loss:   0.03156, ode_loss: 0.0000658, ic_loss: 0.0000026, data_loss: 0.0369946, aw_ode: 2.42, aw_ic: 1.84, aw_data: 2.76
# Epoch  2200, Loss:   0.02939, ode_loss: 0.0000592, ic_loss: 0.0000025, data_loss: 0.0352741, aw_ode: 2.63, aw_ic: 1.85, aw_data: 2.93
# Epoch  2300, Loss:   0.02704, ode_loss: 0.0000539, ic_loss: 0.0000017, data_loss: 0.0307734, aw_ode: 2.84, aw_ic: 1.85, aw_data: 3.09
# Epoch  2400, Loss:   0.02861, ode_loss: 0.0000498, ic_loss: 0.0000024, data_loss: 0.0315474, aw_ode: 3.05, aw_ic: 1.85, aw_data: 3.25
# Epoch  2500, Loss:   0.02597, ode_loss: 0.0000461, ic_loss: 0.0000015, data_loss: 0.0272813, aw_ode: 3.27, aw_ic: 1.86, aw_data: 3.41
# Epoch  2600, Loss:   0.02556, ode_loss: 0.0000445, ic_loss: 0.0000015, data_loss: 0.0268263, aw_ode: 3.49, aw_ic: 1.87, aw_data: 3.57
# Epoch  2700, Loss:   0.02449, ode_loss: 0.0000465, ic_loss: 0.0000017, data_loss: 0.0249724, aw_ode: 3.72, aw_ic: 1.89, aw_data: 3.73
# Epoch  2800, Loss:   0.02327, ode_loss: 0.0000450, ic_loss: 0.0000015, data_loss: 0.0224338, aw_ode: 3.95, aw_ic: 1.93, aw_data: 3.88
# Epoch  2900, Loss:   0.02218, ode_loss: 0.0000408, ic_loss: 0.0000013, data_loss: 0.0207925, aw_ode: 4.17, aw_ic: 1.98, aw_data: 4.04
# Epoch  3000, Loss:   0.02072, ode_loss: 0.0000384, ic_loss: 0.0000009, data_loss: 0.0188942, aw_ode: 4.39, aw_ic: 2.07, aw_data: 4.19
# Epoch  3100, Loss:   0.01877, ode_loss: 0.0000361, ic_loss: 0.0000006, data_loss: 0.0165610, aw_ode: 4.60, aw_ic: 2.21, aw_data: 4.34
# Epoch  3200, Loss:   0.02163, ode_loss: 0.0000340, ic_loss: 0.0000018, data_loss: 0.0189727, aw_ode: 4.81, aw_ic: 2.37, aw_data: 4.49
# Epoch  3300, Loss:   0.02383, ode_loss: 0.0000323, ic_loss: 0.0000028, data_loss: 0.0205970, aw_ode: 5.02, aw_ic: 2.57, aw_data: 4.64
# Epoch  3400, Loss:   0.02336, ode_loss: 0.0000331, ic_loss: 0.0000027, data_loss: 0.0200424, aw_ode: 5.24, aw_ic: 2.78, aw_data: 4.79
# Epoch  3500, Loss:   0.02291, ode_loss: 0.0000316, ic_loss: 0.0000027, data_loss: 0.0189202, aw_ode: 5.45, aw_ic: 3.00, aw_data: 4.94
# Epoch  3600, Loss:   0.01840, ode_loss: 0.0000287, ic_loss: 0.0000015, data_loss: 0.0145715, aw_ode: 5.65, aw_ic: 3.22, aw_data: 5.08
# Epoch  3700, Loss:   0.02539, ode_loss: 0.0000265, ic_loss: 0.0000039, data_loss: 0.0196581, aw_ode: 5.85, aw_ic: 3.44, aw_data: 5.23
# Epoch  3800, Loss:   0.02069, ode_loss: 0.0000255, ic_loss: 0.0000025, data_loss: 0.0152524, aw_ode: 6.05, aw_ic: 3.66, aw_data: 5.37
# Epoch  3900, Loss:   0.02560, ode_loss: 0.0000218, ic_loss: 0.0000040, data_loss: 0.0187270, aw_ode: 6.24, aw_ic: 3.89, aw_data: 5.52
# Epoch  4000, Loss:   0.01833, ode_loss: 0.0000203, ic_loss: 0.0000020, data_loss: 0.0132077, aw_ode: 6.45, aw_ic: 4.11, aw_data: 5.66
# Epoch  4100, Loss:   0.01654, ode_loss: 0.0000196, ic_loss: 0.0000018, data_loss: 0.0118553, aw_ode: 6.66, aw_ic: 4.33, aw_data: 5.80
# Epoch  4200, Loss:   0.01891, ode_loss: 0.0000184, ic_loss: 0.0000025, data_loss: 0.0127123, aw_ode: 6.88, aw_ic: 4.55, aw_data: 5.94
# Epoch  4300, Loss:   0.02656, ode_loss: 0.0000168, ic_loss: 0.0000043, data_loss: 0.0174706, aw_ode: 7.09, aw_ic: 4.77, aw_data: 6.08
# Epoch  4400, Loss:   0.01629, ode_loss: 0.0000152, ic_loss: 0.0000018, data_loss: 0.0105484, aw_ode: 7.31, aw_ic: 4.99, aw_data: 6.22
# Epoch  4500, Loss:   0.02171, ode_loss: 0.0000142, ic_loss: 0.0000031, data_loss: 0.0132384, aw_ode: 7.54, aw_ic: 5.20, aw_data: 6.36
# Epoch  4600, Loss:   0.02616, ode_loss: 0.0000136, ic_loss: 0.0000044, data_loss: 0.0158682, aw_ode: 7.78, aw_ic: 5.42, aw_data: 6.50
# Epoch  4700, Loss:   0.01492, ode_loss: 0.0000138, ic_loss: 0.0000019, data_loss: 0.0094103, aw_ode: 8.03, aw_ic: 5.63, aw_data: 6.64
# Epoch  4800, Loss:   0.01725, ode_loss: 0.0000143, ic_loss: 0.0000022, data_loss: 0.0101340, aw_ode: 8.29, aw_ic: 5.84, aw_data: 6.78
# Epoch  4900, Loss:   0.02198, ode_loss: 0.0000137, ic_loss: 0.0000038, data_loss: 0.0134463, aw_ode: 8.55, aw_ic: 6.07, aw_data: 6.93
# Epoch  5000, Loss:   0.01206, ode_loss: 0.0000177, ic_loss: 0.0000011, data_loss: 0.0072781, aw_ode: 8.82, aw_ic: 6.27, aw_data: 7.06
# Epoch  5100, Loss:   0.01172, ode_loss: 0.0000173, ic_loss: 0.0000012, data_loss: 0.0070984, aw_ode: 9.08, aw_ic: 6.49, aw_data: 7.20
# Epoch  5200, Loss:   0.01819, ode_loss: 0.0000167, ic_loss: 0.0000025, data_loss: 0.0099614, aw_ode: 9.30, aw_ic: 6.69, aw_data: 7.34
# Epoch  5300, Loss:   0.01133, ode_loss: 0.0000162, ic_loss: 0.0000011, data_loss: 0.0064212, aw_ode: 9.52, aw_ic: 6.92, aw_data: 7.48
# Epoch  5400, Loss:   0.02089, ode_loss: 0.0000168, ic_loss: 0.0000031, data_loss: 0.0106348, aw_ode: 9.74, aw_ic: 7.13, aw_data: 7.62
# Epoch  5500, Loss:   0.01453, ode_loss: 0.0000160, ic_loss: 0.0000018, data_loss: 0.0078335, aw_ode: 9.97, aw_ic: 7.35, aw_data: 7.76
# Epoch  5600, Loss:   0.01132, ode_loss: 0.0000152, ic_loss: 0.0000011, data_loss: 0.0059603, aw_ode: 10.19, aw_ic: 7.57, aw_data: 7.90
# Epoch  5700, Loss:   0.00903, ode_loss: 0.0000150, ic_loss: 0.0000007, data_loss: 0.0047427, aw_ode: 10.41, aw_ic: 7.78, aw_data: 8.04
# Epoch  5800, Loss:   0.01292, ode_loss: 0.0000155, ic_loss: 0.0000014, data_loss: 0.0059679, aw_ode: 10.64, aw_ic: 7.99, aw_data: 8.17
# Epoch  5900, Loss:   0.02813, ode_loss: 0.0000146, ic_loss: 0.0000046, data_loss: 0.0130568, aw_ode: 10.88, aw_ic: 8.20, aw_data: 8.31
# Epoch  6000, Loss:   0.01266, ode_loss: 0.0000136, ic_loss: 0.0000015, data_loss: 0.0061959, aw_ode: 11.12, aw_ic: 8.42, aw_data: 8.45
# Epoch  6100, Loss:   0.01056, ode_loss: 0.0000141, ic_loss: 0.0000010, data_loss: 0.0048471, aw_ode: 11.36, aw_ic: 8.62, aw_data: 8.59
# Epoch  6200, Loss:   0.02277, ode_loss: 0.0000138, ic_loss: 0.0000034, data_loss: 0.0102693, aw_ode: 11.61, aw_ic: 8.83, aw_data: 8.72
# Epoch  6300, Loss:   0.00877, ode_loss: 0.0000141, ic_loss: 0.0000008, data_loss: 0.0039268, aw_ode: 11.86, aw_ic: 9.05, aw_data: 8.86
# Epoch  6400, Loss:   0.02306, ode_loss: 0.0000133, ic_loss: 0.0000033, data_loss: 0.0099157, aw_ode: 12.11, aw_ic: 9.26, aw_data: 9.00
# Epoch  6500, Loss:   0.01239, ode_loss: 0.0000192, ic_loss: 0.0000014, data_loss: 0.0051065, aw_ode: 12.38, aw_ic: 9.48, aw_data: 9.14
# Epoch  6600, Loss:   0.02148, ode_loss: 0.0000195, ic_loss: 0.0000029, data_loss: 0.0083892, aw_ode: 12.62, aw_ic: 9.69, aw_data: 9.28
# Epoch  6700, Loss:   0.02505, ode_loss: 0.0000179, ic_loss: 0.0000034, data_loss: 0.0093985, aw_ode: 12.83, aw_ic: 9.90, aw_data: 9.42
# Epoch  6800, Loss:   0.00948, ode_loss: 0.0000182, ic_loss: 0.0000009, data_loss: 0.0037062, aw_ode: 13.05, aw_ic: 10.11, aw_data: 9.55
# Epoch  6900, Loss:   0.00924, ode_loss: 0.0000156, ic_loss: 0.0000008, data_loss: 0.0036074, aw_ode: 13.27, aw_ic: 10.32, aw_data: 9.69
# Epoch  7000, Loss:   0.01075, ode_loss: 0.0000206, ic_loss: 0.0000011, data_loss: 0.0040264, aw_ode: 13.52, aw_ic: 10.53, aw_data: 9.82
# Epoch  7100, Loss:   0.03365, ode_loss: 0.0000191, ic_loss: 0.0000052, data_loss: 0.0125104, aw_ode: 13.73, aw_ic: 10.75, aw_data: 9.96
# Epoch  7200, Loss:   0.01051, ode_loss: 0.0000180, ic_loss: 0.0000013, data_loss: 0.0042884, aw_ode: 13.94, aw_ic: 10.96, aw_data: 10.10
# Epoch  7300, Loss:   0.01053, ode_loss: 0.0000184, ic_loss: 0.0000010, data_loss: 0.0036606, aw_ode: 14.15, aw_ic: 11.16, aw_data: 10.24
# Epoch  7400, Loss:   0.01975, ode_loss: 0.0000169, ic_loss: 0.0000023, data_loss: 0.0065857, aw_ode: 14.37, aw_ic: 11.37, aw_data: 10.37
# Epoch  7500, Loss:   0.00962, ode_loss: 0.0000172, ic_loss: 0.0000010, data_loss: 0.0035840, aw_ode: 14.59, aw_ic: 11.58, aw_data: 10.51
# Epoch  7600, Loss:   0.02759, ode_loss: 0.0000161, ic_loss: 0.0000039, data_loss: 0.0097866, aw_ode: 14.82, aw_ic: 11.79, aw_data: 10.65
# Epoch  7700, Loss:   0.00885, ode_loss: 0.0000176, ic_loss: 0.0000008, data_loss: 0.0029460, aw_ode: 15.05, aw_ic: 12.01, aw_data: 10.79
# Epoch  7800, Loss:   0.01903, ode_loss: 0.0000168, ic_loss: 0.0000022, data_loss: 0.0058363, aw_ode: 15.29, aw_ic: 12.22, aw_data: 10.93
# Epoch  7900, Loss:   0.02532, ode_loss: 0.0000156, ic_loss: 0.0000033, data_loss: 0.0083861, aw_ode: 15.52, aw_ic: 12.43, aw_data: 11.07
# Epoch  8000, Loss:   0.02154, ode_loss: 0.0000145, ic_loss: 0.0000030, data_loss: 0.0078516, aw_ode: 15.75, aw_ic: 12.66, aw_data: 11.21
# Epoch  8100, Loss:   0.01740, ode_loss: 0.0000146, ic_loss: 0.0000022, data_loss: 0.0061912, aw_ode: 15.98, aw_ic: 12.87, aw_data: 11.35
# Epoch  8200, Loss:   0.02194, ode_loss: 0.0000145, ic_loss: 0.0000030, data_loss: 0.0076194, aw_ode: 16.21, aw_ic: 13.09, aw_data: 11.49
# Epoch  8300, Loss:   0.02692, ode_loss: 0.0000154, ic_loss: 0.0000035, data_loss: 0.0085385, aw_ode: 16.45, aw_ic: 13.30, aw_data: 11.63
# Epoch  8400, Loss:   0.01493, ode_loss: 0.0000164, ic_loss: 0.0000016, data_loss: 0.0044314, aw_ode: 16.68, aw_ic: 13.52, aw_data: 11.77
# Epoch  8500, Loss:   0.01236, ode_loss: 0.0000158, ic_loss: 0.0000012, data_loss: 0.0037778, aw_ode: 16.92, aw_ic: 13.74, aw_data: 11.91
# Epoch  8600, Loss:   0.01817, ode_loss: 0.0000168, ic_loss: 0.0000023, data_loss: 0.0059677, aw_ode: 17.15, aw_ic: 13.96, aw_data: 12.06
# Epoch  8700, Loss:   0.01807, ode_loss: 0.0000181, ic_loss: 0.0000019, data_loss: 0.0051557, aw_ode: 17.40, aw_ic: 14.17, aw_data: 12.19
# Epoch  8800, Loss:   0.02227, ode_loss: 0.0000167, ic_loss: 0.0000029, data_loss: 0.0069251, aw_ode: 17.63, aw_ic: 14.41, aw_data: 12.34
# Epoch  8900, Loss:   0.02003, ode_loss: 0.0000184, ic_loss: 0.0000022, data_loss: 0.0055552, aw_ode: 17.87, aw_ic: 14.62, aw_data: 12.48
# Epoch  9000, Loss:   0.02855, ode_loss: 0.0000176, ic_loss: 0.0000035, data_loss: 0.0084184, aw_ode: 18.10, aw_ic: 14.83, aw_data: 12.62
# Epoch  9100, Loss:   0.02244, ode_loss: 0.0000171, ic_loss: 0.0000028, data_loss: 0.0064760, aw_ode: 18.34, aw_ic: 15.06, aw_data: 12.77
# Epoch  9200, Loss:   0.01167, ode_loss: 0.0000184, ic_loss: 0.0000011, data_loss: 0.0030720, aw_ode: 18.57, aw_ic: 15.28, aw_data: 12.90
# Epoch  9300, Loss:   0.02389, ode_loss: 0.0000176, ic_loss: 0.0000029, data_loss: 0.0067428, aw_ode: 18.80, aw_ic: 15.50, aw_data: 13.05
# Epoch  9400, Loss:   0.01783, ode_loss: 0.0000179, ic_loss: 0.0000019, data_loss: 0.0046192, aw_ode: 19.03, aw_ic: 15.72, aw_data: 13.19
# Epoch  9500, Loss:   0.01217, ode_loss: 0.0000184, ic_loss: 0.0000011, data_loss: 0.0029600, aw_ode: 19.26, aw_ic: 15.94, aw_data: 13.34
# Epoch  9600, Loss:   0.00953, ode_loss: 0.0000174, ic_loss: 0.0000010, data_loss: 0.0026195, aw_ode: 19.49, aw_ic: 16.17, aw_data: 13.48
# Epoch  9700, Loss:   0.01481, ode_loss: 0.0000180, ic_loss: 0.0000015, data_loss: 0.0037730, aw_ode: 19.71, aw_ic: 16.38, aw_data: 13.62
# Epoch  9800, Loss:   0.02023, ode_loss: 0.0000181, ic_loss: 0.0000021, data_loss: 0.0050511, aw_ode: 19.94, aw_ic: 16.60, aw_data: 13.76
# Epoch  9900, Loss:   0.01709, ode_loss: 0.0000187, ic_loss: 0.0000016, data_loss: 0.0041798, aw_ode: 20.17, aw_ic: 16.82, aw_data: 13.91
# Epoch 10000, Loss:   0.02555, ode_loss: 0.0000192, ic_loss: 0.0000028, data_loss: 0.0061791, aw_ode: 20.40, aw_ic: 17.04, aw_data: 14.05
# <All keys matched successfully>

# %%
# finish the wandb run
if wandb_on:
    wandb.finish()

# %%
print(net(t0))
# Out:
# tensor([8.9932e-01, 9.9764e-02, 4.8758e-05], grad_fn=<AddBackward0>)

# %%
fig, ax = plt.subplots(1,1)
ax.plot(losses, label='loss')
ax.plot(ode_losses, label='ODE loss')
ax.plot(ic_losses, label='IC loss')
ax.legend()
ax.set_ylim(0, 0.001)
# Out:
# (0.0, 0.001)

# %%
net_cpu = net.to('cpu')

U = net_cpu(torch.tensor(t).float().view(-1,1))
S_net = U[:,0]
I_net = U[:,1]
R_net = U[:,2]

# Plot numerical solution
fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.plot(t, S_net.detach().numpy(), linestyle='-', label='S_net', color='blue')
ax.plot(t, I_net.detach().numpy(), linestyle='-', label='I_net', color='red')
ax.plot(t, R_net.detach().numpy(), linestyle='-', label='R_net', color='green')
ax.plot(t, S_data.clone().to('cpu'), linestyle='--', label='S_num', color='blue')
ax.plot(t, I_data.clone().to('cpu'), linestyle='--', label='I_num', color='red')
ax.plot(t, R_data.clone().to('cpu'), linestyle='--', label='R_num', color='green')

ax.set_xlabel('Time [days]')
ax.set_ylabel('S(t), I(t), R(t) [Count]')
ax.legend() 
ax.set_title('Numerical Solution to SIR model')
# Out:
# Text(0.5, 1.0, 'Numerical Solution to SIR model')

# %%
# check stuff using numpy and gradient
S_net_np = S_net.detach().numpy()
I_net_np = I_net.detach().numpy()
R_net_np = R_net.detach().numpy()

# Running the sdfh nioa
dSdt = np.gradient(S_net_np)
dIdt = np.gradient(I_net_np)
dRdt = np.gradient(R_net_np)

rhs_S = beta * S_net_np * I_net_np
rhs_I = -beta * S_net_np * I_net_np + alpha * I_net_np
rhs_R = -alpha * I_net_np

# %%
fig, ax = plt.subplots(1,1)
ax.plot(dSdt, color='blue', linestyle='-', label='dSdt')
ax.plot(rhs_S, color='blue', linestyle='--', label='rhs_S')
ax.plot(dIdt, color='red', linestyle='-', label='dSdt')
ax.plot(rhs_I, color='red', linestyle='--', label='rhs_S')
ax.plot(dRdt, color='green', linestyle='-', label='dSdt')
ax.plot(rhs_R, color='green', linestyle='--', label='rhs_S')
ax.set_ylim(-0.01, 0.01)
ax.legend()

# %%
t_data_batch
# Out:
# array([], dtype=float32)

# %%
# Vectors for each of the adaptive weights
aw_ode = [1.01, 1.04, 1.04, 1.04, 1.04, 1.05, 1.07, 1.12, 1.21, 1.32, 1.44, 1.57, 1.68, 1.80, 1.92, 2.05, 2.18, 2.34, 2.48, 2.61, 2.75, 2.88, 3.02, 3.15, 3.30, 3.43, 3.57, 3.71, 3.84]
aw_ic = [1.01, 1.55, 1.86, 1.90, 1.90, 1.90, 1.90, 1.90, 1.90, 1.90, 1.90, 1.91, 1.93, 2.00, 2.13, 2.43, 2.77, 3.05, 3.43, 3.78, 4.12, 4.51, 4.86, 5.32, 5.64, 6.06, 6.47, 6.92, 7.26]
aw_data = [1.01, 1.08, 1.08, 1.09, 1.11, 1.15, 1.23, 1.42, 1.73, 2.11, 2.51, 2.85, 3.22, 3.61, 3.94, 4.26, 4.55, 4.74, 5.02, 5.27, 5.47, 5.77, 6.01, 6.34, 6.64, 7.02, 7.42, 7.83, 8.21]

# Creating a vector for the epochs
epochs = [i for i in range(1, len(aw_ode) * 100 + 1, 100)]

# Plotting the adaptive weights over epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs, aw_ode, label='aw_ode', marker='o', color='black')
plt.plot(epochs, aw_ic, label='aw_ic', marker='x', color='black')
plt.plot(epochs, aw_data, label='aw_data', marker='^',color='black')

plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Adaptive Weight Values', fontsize=20)
#plt.title('Adaptive Weights (aw_ode, aw_ic, aw_data) Over Epochs')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(fontsize=16)
plt.grid(True)
plt.show()
