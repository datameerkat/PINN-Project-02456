# %%
import tqdm as notebook_tqdm
import torch
from torch import nn

import sklearn
import numpy as np
import matplotlib.pyplot as plt

#import torch.nn.functional as F
#import torch.optim as optim
#import torch.nn.init as init

#%matplotlib inline
#import matplotlib

#from torch.nn.parameter import Parameter

# %%
minx = -4*np.pi
maxx = 4*np.pi
resolution_x = 1000

x = np.arange(minx, maxx, (maxx-minx)/resolution_x)
y = np.sin(x)

data = [x,y]

# %%
plt.figure()
plt.plot(data[0],data[1])
plt.title("True sine curve")
plt.xlabel("angle x in radians")
plt.ylabel("sin(x)")
plt.show()

# %%
percentage_train = 0.7
percentage_test = 0.2
percentage_validation = 1 - percentage_train - percentage_test

N_train = np.floor(percentage_train*np.size(data[0]))
N_test = np.floor(percentage_test*np.size(data[0]))
N_validation = np.floor(percentage_validation*np.size(data[0]))

train =
